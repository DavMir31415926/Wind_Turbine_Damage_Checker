# %%
import os
import random
from pathlib import Path

# Define paths relative to your notebook location
base_path = Path("Blades Damages Images + Labels/NordTank586x371")
images_dir = base_path / "images"
labels_dir = base_path / "labels"

def analyze_dataset():
    """Analyze the dataset and categorize files by damage presence"""
    damage_files = []
    non_damage_files = []
    
    # Get all label files
    label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
    
    print(f"Found {len(label_files)} label files")
    
    for label_file in label_files:
        label_path = labels_dir / label_file
        
        # Check if corresponding image exists (try both .png and .jpg)
        img_name_png = label_file.replace('.txt', '.png')
        img_name_jpg = label_file.replace('.txt', '.jpg')
        
        img_path = None
        if (images_dir / img_name_png).exists():
            img_path = images_dir / img_name_png
            img_name = img_name_png
        elif (images_dir / img_name_jpg).exists():
            img_path = images_dir / img_name_jpg
            img_name = img_name_jpg
        
        if img_path is None:
            print(f"No image found for {label_file}")
            continue
            
        # Read label file and check for class 0 (damage)
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        if not lines:  # Empty file = no annotations = non-damage
            non_damage_files.append((img_name, label_file))
            continue
            
        # Check if any annotation is class 0 (damage)
        has_damage = False
        for line in lines:
            if line.strip():  # Skip empty lines
                class_id = int(line.strip().split()[0])
                if class_id == 0:  # Damage class
                    has_damage = True
                    break
        
        if has_damage:
            damage_files.append((img_name, label_file))
        else:
            non_damage_files.append((img_name, label_file))
    
    return damage_files, non_damage_files

# Test if paths exist first
print(f"Images directory exists: {images_dir.exists()}")
print(f"Labels directory exists: {labels_dir.exists()}")

if images_dir.exists() and labels_dir.exists():
    # Analyze the dataset
    damage_pairs, non_damage_pairs = analyze_dataset()
    
    print(f"Found {len(damage_pairs)} images with damage")
    print(f"Found {len(non_damage_pairs)} images without damage")
else:
    print("Directory paths are incorrect!")
# Out:
# Images directory exists: True
# Labels directory exists: True
# Found 2996 label files
# No image found for labels.txt
# Found 563 images with damage
# Found 2432 images without damage

# %%
# Sample the desired amounts
max_damage = min(100, len(damage_pairs))
max_non_damage = min(400, len(non_damage_pairs))

# Create final selection
selected_damage = random.sample(damage_pairs, max_damage)
selected_non_damage = random.sample(non_damage_pairs, max_non_damage)

# Combine all selected pairs
all_selected_pairs = selected_damage + selected_non_damage
random.shuffle(all_selected_pairs)  # Shuffle for training

# Extract separate lists
selected_images = [pair[0] for pair in all_selected_pairs]
selected_labels = [pair[1] for pair in all_selected_pairs]

print(f"Final training selection:")
print(f"- {len(selected_damage)} damage examples")
print(f"- {len(selected_non_damage)} non-damage examples") 
print(f"- {len(all_selected_pairs)} total examples")

# Show some examples
print(f"\nFirst 5 selected files:")
for i in range(min(5, len(selected_images))):
    print(f"  {selected_images[i]} <-> {selected_labels[i]}")

# Create train/validation split
from sklearn.model_selection import train_test_split
train_pairs, val_pairs = train_test_split(all_selected_pairs, test_size=0.2, random_state=42)

print(f"\nTrain/Validation split:")
print(f"- Training: {len(train_pairs)} examples")
print(f"- Validation: {len(val_pairs)} examples")
# Out:
# Final training selection:
# - 100 damage examples
# - 400 non-damage examples
# - 500 total examples
#
# First 5 selected files:
#   DJI_0785_02_06.png <-> DJI_0785_02_06.txt
#   DJI_0583_05_05.png <-> DJI_0583_05_05.txt
#   DJI_0770_02_04.png <-> DJI_0770_02_04.txt
#   DJI_0022_04_03.png <-> DJI_0022_04_03.txt
#   DJI_0367_02_08.png <-> DJI_0367_02_08.txt
#
# Train/Validation split:
# - Training: 400 examples
# - Validation: 100 examples

# %%
import os
import random
from pathlib import Path

# Step 1: Recreate base path
base_path = Path("Blades Damages Images + Labels/NordTank586x371")
images_dir = base_path / "images"
labels_dir = base_path / "labels"

# Step 2: Recreate data selection (simplified version)
def analyze_dataset():
    damage_files = []
    non_damage_files = []
    
    label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
    
    for label_file in label_files:
        label_path = labels_dir / label_file
        
        # Check if corresponding image exists
        img_name_png = label_file.replace('.txt', '.png')
        if not (images_dir / img_name_png).exists():
            continue
            
        # Read label file and check for class 0 (damage)
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        if not lines:
            non_damage_files.append((img_name_png, label_file))
            continue
            
        has_damage = False
        for line in lines:
            if line.strip():
                class_id = int(line.strip().split()[0])
                if class_id == 0:  # Damage class
                    has_damage = True
                    break
        
        if has_damage:
            damage_files.append((img_name_png, label_file))
        else:
            non_damage_files.append((img_name_png, label_file))
    
    return damage_files, non_damage_files

# Step 3: Recreate selection
damage_pairs, non_damage_pairs = analyze_dataset()
print(f"Found {len(damage_pairs)} damage images")
print(f"Found {len(non_damage_pairs)} non-damage images")

# Sample the desired amounts
max_damage = min(100, len(damage_pairs))
max_non_damage = min(400, len(non_damage_pairs))

selected_damage = random.sample(damage_pairs, max_damage)
selected_non_damage = random.sample(non_damage_pairs, max_non_damage)

# Combine and split
all_selected_pairs = selected_damage + selected_non_damage
random.shuffle(all_selected_pairs)

# Create train/val split
split_point = int(0.8 * len(all_selected_pairs))
train_pairs = all_selected_pairs[:split_point]
val_pairs = all_selected_pairs[split_point:]

print(f"Training: {len(train_pairs)} examples")
print(f"Validation: {len(val_pairs)} examples")
# Out:
# Found 563 damage images
# Found 2432 non-damage images
# Training: 400 examples
# Validation: 100 examples

# %%
# Step 4: Create corrected train and val lists with full relative paths
train_files = [pair[0] for pair in train_pairs]
val_files = [pair[0] for pair in val_pairs]

# Write train list with correct paths
with open('train.txt', 'w') as f:
    for img_name in train_files:
        f.write(f"{base_path}/images/{img_name}\n")

# Write val list with correct paths
with open('val.txt', 'w') as f:
    for img_name in val_files:
        f.write(f"{base_path}/images/{img_name}\n")

print(f"Updated train.txt with {len(train_files)} images")
print(f"Updated val.txt with {len(val_files)} images")

# Update the dataset.yaml to use the corrected file lists
dataset_config = """
train: train.txt
val: val.txt

nc: 2
names: ['damage', 'dirty']
"""

with open('dataset.yaml', 'w') as f:
    f.write(dataset_config)

print("Updated dataset.yaml with correct paths")
# Out:
# Updated train.txt with 400 images
# Updated val.txt with 100 images
# Updated dataset.yaml with correct paths

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')
results = model.train(
    data='dataset.yaml',
    epochs=50,
    imgsz=640,
    batch=16,
    name='wind_turbine_damage'
)
# Out:
# Ultralytics 8.3.202  Python-3.12.7 torch-2.8.0+cpu CPU (Intel Core i5-1035G4 1.10GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=wind_turbine_damage4, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\dmirk\Sulzer Schmid\runs\detect\wind_turbine_damage4, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.40.0 ms, read: 6.81.7 MB/s, size: 195.6 KB)
# train: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 400 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 400/400 126.0it/s 3.2s0.1s
# train: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# val: Fast image access  (ping: 0.40.1 ms, read: 5.61.2 MB/s, size: 196.0 KB)
# val: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 100 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 100/100 128.0it/s 0.8s1s
# val: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# Plotting labels to C:\Users\dmirk\Sulzer Schmid\runs\detect\wind_turbine_damage4\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\dmirk\Sulzer Schmid\runs\detect\wind_turbine_damage4
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.757      3.377      1.277         78        640: 100% ━━━━━━━━━━━━ 25/25 0.0it/s 8:4911.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.2it/s 22.0s10.2s
#                    all        100        294    0.00508      0.689      0.173     0.0921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.719      2.504      1.277        150        640: 100% ━━━━━━━━━━━━ 25/25 0.0it/s 2:42:0310.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 12.8s6.2s
#                    all        100        294      0.555      0.152      0.062     0.0239
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G       1.76      2.251      1.302         71        640: 100% ━━━━━━━━━━━━ 25/25 0.2it/s 2:316.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 13.0s6.1s
#                    all        100        294      0.437      0.154      0.142     0.0493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G        1.8      2.215      1.322         92        640: 100% ━━━━━━━━━━━━ 25/25 0.0it/s 4:28:049.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 15.5s7.2ss
#                    all        100        294      0.783      0.199      0.343       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G       1.84      2.199      1.338        116        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 3:449.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 15.0s6.6ss
#                    all        100        294      0.271      0.557      0.345      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.806      2.039      1.322         78        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 3:5411.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 14.8s6.7ss
#                    all        100        294      0.249      0.516       0.39      0.227
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.786      1.976      1.308         62        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 3:499.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 14.7s6.8s
#                    all        100        294      0.438      0.271      0.268      0.122
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.767      1.898      1.314         83        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:209.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.2it/s 17.5s7.7ss
#                    all        100        294        0.3      0.534      0.362      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G      1.727      1.828       1.27         79        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:089.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 14.7s6.8s
#                    all        100        294      0.579       0.48      0.516      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G      1.758      1.779      1.274         76        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:1010.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 15.2s7.2ss
#                    all        100        294      0.576      0.326      0.439      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G      1.735      1.725      1.257         62        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:2410.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.2it/s 16.7s8.0ss
#                    all        100        294      0.445      0.477      0.417      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G      1.698      1.715      1.254         82        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:0810.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 15.2s7.1s
#                    all        100        294      0.541       0.36      0.391      0.169
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G      1.628      1.564      1.216         84        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:059.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 15.0s7.0s
#                    all        100        294      0.504      0.447      0.454      0.214
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G      1.635      1.595      1.239        104        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:019.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 14.9s6.9ss
#                    all        100        294      0.557      0.518      0.507      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G      1.616      1.534        1.2         67        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:079.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 14.9s7.0ss
#                    all        100        294      0.558      0.547      0.584      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G      1.665      1.565      1.232         97        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 3:589.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 13.3s6.4s
#                    all        100        294      0.482      0.581      0.545      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G      1.559      1.453      1.175         75        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:019.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 15.4s7.4s
#                    all        100        294      0.575      0.559      0.567        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      1.576      1.409        1.2        109        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:099.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.2it/s 16.6s7.9ss
#                    all        100        294      0.554      0.524      0.541      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G      1.542      1.402      1.171         59        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 3:569.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 14.1s6.7s
#                    all        100        294      0.584      0.539      0.566      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G       1.58      1.384      1.187         74        640: 100% ━━━━━━━━━━━━ 25/25 0.1it/s 4:119.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 14.0s6.6s
#                    all        100        294       0.64      0.546      0.619      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G      1
2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 15.3s7.1ss
#                    all        100        294      0.742      0.657      0.715      0.462
#
# 50 epochs completed in 10.825 hours.
# Optimizer stripped from C:\Users\dmirk\Sulzer Schmid\runs\detect\wind_turbine_damage4\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\dmirk\Sulzer Schmid\runs\detect\wind_turbine_damage4\weights\best.pt, 6.2MB
#
# Validating C:\Users\dmirk\Sulzer Schmid\runs\detect\wind_turbine_damage4\weights\best.pt...
# Ultralytics 8.3.202  Python-3.12.7 torch-2.8.0+cpu CPU (Intel Core i5-1035G4 1.10GHz)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 0.3it/s 12.4s5.8s
#                    all        100        294      0.733      0.655      0.714      0.469
#                 damage         23         23      0.739      0.826      0.837      0.649
#                  dirty         81        271      0.727      0.483       0.59      0.289
# Speed: 1.1ms preprocess, 97.8ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to C:\Users\dmirk\Sulzer Schmid\runs\detect\wind_turbine_damage4

# %%
#Test Model With Unused Images
import os
import random
from pathlib import Path
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# Load your trained model
model = YOLO('runs/detect/wind_turbine_damage4/weights/best.pt')

# Set up paths
base_path = Path("Blades Damages Images + Labels/NordTank586x371")
images_dir = base_path / "images"
labels_dir = base_path / "labels"

# Get all available images and their classes
def get_unused_images():
    """Find images that weren't used in training"""
    damage_files = []
    dirty_files = []
    
    # Read the training file list to exclude used images
    with open('train.txt', 'r') as f:
        train_images = set(line.strip().split('/')[-1] for line in f)
    with open('val.txt', 'r') as f:
        val_images = set(line.strip().split('/')[-1] for line in f)
    
    used_images = train_images.union(val_images)
    
    # Categorize unused images
    label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
    
    for label_file in label_files:
        img_name = label_file.replace('.txt', '.png')
        
        # Skip if this image was used in training/validation
        if img_name in used_images:
            continue
            
        # Check if image exists
        if not (images_dir / img_name).exists():
            continue
            
        # Check class
        label_path = labels_dir / label_file
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        if not lines:
            dirty_files.append(img_name)
            continue
            
        has_damage = False
        for line in lines:
            if line.strip():
                class_id = int(line.strip().split()[0])
                if class_id == 0:  # Damage class
                    has_damage = True
                    break
        
        if has_damage:
            damage_files.append(img_name)
        else:
            dirty_files.append(img_name)
    
    return damage_files, dirty_files

# Get unused images
unused_damage, unused_dirty = get_unused_images()
print(f"Available unused images: {len(unused_damage)} damage, {len(unused_dirty)} dirty")

# Sample test set
test_damage = random.sample(unused_damage, min(20, len(unused_damage)))
test_dirty = random.sample(unused_dirty, min(80, len(unused_dirty)))

print(f"Testing on: {len(test_damage)} damage images, {len(test_dirty)} dirty images")

# Test the model
def test_model_on_images(image_list, true_class_name):
    """Test model on a list of images and return results"""
    results = []
    
    for img_name in image_list:
        img_path = images_dir / img_name
        
        # Run prediction
        pred_results = model(str(img_path))
        
        # Extract predictions
        detections = []
        if len(pred_results[0].boxes) > 0:
            boxes = pred_results[0].boxes
            for box in boxes:
                class_id = int(box.cls[0].item())
                confidence = float(box.conf[0].item())
                class_name = "damage" if class_id == 0 else "dirty"
                detections.append((class_name, confidence))
        
        results.append({
            'image': img_name,
            'true_class': true_class_name,
            'detections': detections
        })
    
    return results

# Run tests
print("\nTesting damage images...")
damage_results = test_model_on_images(test_damage, 'damage')

print("Testing dirty images...")
dirty_results = test_model_on_images(test_dirty, 'dirty')

# Analyze results
def analyze_results(results, target_class):
    """Analyze prediction accuracy"""
    correct = 0
    total = len(results)
    
    print(f"\n--- {target_class.upper()} IMAGES ANALYSIS ---")
    
    for result in results:
        img_name = result['image']
        detections = result['detections']
        
        # Check if any detection matches the true class
        predicted_classes = [det[0] for det in detections]
        has_correct_prediction = target_class in predicted_classes
        
        if has_correct_prediction:
            correct += 1
            
        print(f"{img_name}: {detections if detections else 'No detections'}")
    
    accuracy = correct / total if total > 0 else 0
    print(f"\nAccuracy: {correct}/{total} = {accuracy:.3f}")
    return accuracy

# Analyze results
damage_accuracy = analyze_results(damage_results, 'damage')
dirty_accuracy = analyze_results(dirty_results, 'dirty')

print(f"\n=== OVERALL RESULTS ===")
print(f"Damage detection accuracy: {damage_accuracy:.3f}")
print(f"Dirty detection accuracy: {dirty_accuracy:.3f}")
print(f"Overall accuracy: {(damage_accuracy * len(test_damage) + dirty_accuracy * len(test_dirty)) / (len(test_damage) + len(test_dirty)):.3f}")

# Optional: Show some example predictions visually
print(f"\nModel saved results to: runs/detect/wind_turbine_damage4/")
print("Run model.predict() on individual images to see visual results")
# Out:
# Available unused images: 463 damage, 2032 dirty
# Testing on: 20 damage images, 80 dirty images
#
# Testing damage images...
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0618_01_07.png: 416x640 1 damage, 1 dirty, 269.9ms
# Speed: 17.5ms preprocess, 269.9ms inference, 10.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0623_02_08.png: 416x640 1 damage, 114.2ms
# Speed: 6.3ms preprocess, 114.2ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0631_07_04.png: 416x640 1 damage, 112.1ms
# Speed: 4.6ms preprocess, 112.1ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0748_04_07.png: 416x640 1 damage, 7 dirtys, 112.4ms
# Speed: 5.5ms preprocess, 112.4ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0584_04_04.png: 416x640 1 damage, 243.3ms
# Speed: 4.3ms preprocess, 243.3ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0585_08_05.png: 416x640 2 damages, 120.7ms
# Speed: 4.9ms preprocess, 120.7ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0632_05_04.png: 416x640 2 damages, 115.9ms
# Speed: 4.8ms preprocess, 115.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0625_07_05.png: 416x640 2 damages, 117.8ms
# Speed: 4.9ms preprocess, 117.8ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0618_02_07.png: 416x640 1 damage, 1 dirty, 109.1ms
# Speed: 4.2ms preprocess, 109.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0620_07_05.png: 416x640 1 damage, 2 dirtys, 107.5ms
# Speed: 4.8ms preprocess, 107.5ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0701_05_04.png: 416x640 1 damage, 116.0ms
# Speed: 4.7ms preprocess, 116.0ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0738_03_01.png: 416x640 1 damage, 128.8ms
# Speed: 4.1ms preprocess, 128.8ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0744_03_02.png: 416x640 1 damage, 117.5ms
# Speed: 4.7ms preprocess, 117.5ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0632_08_02.png: 416x640 2 damages, 119.8ms
# Speed: 3.6ms preprocess, 119.8ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0753_05_07.png: 416x640 (no detections), 117.7ms
# Speed: 4.5ms preprocess, 117.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0706_07_05.png: 416x640 1 damage, 118.9ms
# Speed: 4.8ms preprocess, 118.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0751_02_06.png: 416x640 1 damage, 122.2ms
# Speed: 3.6ms preprocess, 122.2ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0751_02_01.png: 416x640 1 damage, 4 dirtys, 111.9ms
# Speed: 4.1ms preprocess, 111.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0696
3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0788_03_07.png: 416x640 (no detections), 126.0ms
# Speed: 4.0ms preprocess, 126.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0995_03_03.png: 416x640 1 dirty, 118.4ms
# Speed: 4.8ms preprocess, 118.4ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0015_03_03.png: 416x640 4 dirtys, 133.2ms
# Speed: 3.8ms preprocess, 133.2ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0603_02_04.png: 416x640 (no detections), 120.8ms
# Speed: 4.5ms preprocess, 120.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0198_02_08.png: 416x640 5 dirtys, 123.1ms
# Speed: 4.2ms preprocess, 123.1ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0428_04_02.png: 416x640 (no detections), 131.3ms
# Speed: 3.9ms preprocess, 131.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0391_05_05.png: 416x640 7 dirtys, 123.7ms
# Speed: 4.8ms preprocess, 123.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0217_01_04.png: 416x640 10 dirtys, 126.1ms
# Speed: 4.3ms preprocess, 126.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0788_02_05.png: 416x640 (no detections), 135.3ms
# Speed: 4.6ms preprocess, 135.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0223_04_03.png: 416x640 6 dirtys, 126.2ms
# Speed: 4.2ms preprocess, 126.2ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0282_03_04.png: 416x640 1 dirty, 197.5ms
# Speed: 3.9ms preprocess, 197.5ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0782_05_02.png: 416x640 (no detections), 136.5ms
# Speed: 4.5ms preprocess, 136.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0784_01_05.png: 416x640 (no detections), 125.5ms
# Speed: 4.4ms preprocess, 125.5ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0272_06_02.png: 416x640 1 dirty, 123.0ms
# Speed: 4.1ms preprocess, 123.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0975_04_09.png: 416x640 4 dirtys, 132.2ms
# Speed: 4.0ms preprocess, 132.2ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0398_05_06.png: 416x640 4 dirtys, 136.1ms
# Speed: 4.0ms preprocess, 136.1ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0585_03_01.png: 416x640 3 dirtys, 128.8ms
# Speed: 5.2ms preprocess, 128.8ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# --- DAMAGE IMAGES ANALYSIS ---
# DJI_0618_01_07.png: [('damage', 0.8017922639846802), ('dirty', 0.30027103424072266)]
# DJI_0623_02_08.png: [('damage', 0.8357582092285156)]
# DJI_0631_07_04.png: [('damage', 0.9017231464385986)]
# DJI_0748_04_07.png: [('damage', 0.7733343243598938), ('dirty', 0.6830042600631714), ('dirty', 0.6585315465927124), ('dirty', 0.6472994089126587), ('dirty', 0.46518269181251526), ('dirty', 0.38773322105407715), ('dirty', 0.3407606780529022), ('dirty', 0.27605730295181274)]
# DJI_0584_04_04.png: [('damage', 0.8639198541641235)]
# DJI_0585_08_05.png: [('damage', 0.5764049291610718), ('damage', 0.5428641438484192)]
# DJI_0632_05_04.png: [('damage', 0.8739198446273804), ('damage', 0.55291348695755)]
# DJI_0625_07_05.png: [('damage', 0.8465140461921692), ('damage', 0.4024728536605835)]
# DJI_0618_02_07.png: [('damage', 0.7838900685310364), ('dirty', 0.2561824917793274)]
# DJI_0620_07_05.png: [('damage', 0.8283264636993408), ('dirty', 0.6496034264564514), ('dirty', 0.4858512282371521)]
# DJI_0701_05_04.png: [('damage', 0.44199100136756897)]
# DJI_0738_03_01.png: [('damage', 0.7205304503440857)]
# DJI_0744_03_02.png: [('damage', 0.8194141387939453)]
# DJI_0632_08_02.png: [('damage', 0.7310647964477539), ('damage', 0.4533078074455261)]
# DJI_0753_05_07.png: No detections
# DJI_0706_07_05.png: [('damage', 0.8323799967765808)]
# DJI_0751_02_06.png: [('damage', 0.6813675165176392)]
# DJI_0751_02_01.png: [('dirty', 0.4709257483482361), ('damage', 0.33455026149749756), ('dirty', 0.32376837730407715), ('dirty', 0.31912943720817566), ('dirty', 0.2858508229255676)]
# DJI_0696_03_03.png: [('damage', 0.8048827052116394)]
# DJI_0749_04_07.png: [('damage', 0.7767220139503479), ('dirty', 0.6489936709403992), ('dirty', 0.5600305199623108), ('dirty', 0.5238230228424072)]
#
# Accuracy: 19/20 = 0.950
#
# --- DIRTY IMAGES ANALYSIS ---
# DJI_0251_06_02.png: [('dirty', 0.8957251906394958), ('dirty', 0.7666831612586975), ('dirty', 0.720863401889801), ('dirty', 0.40337273478507996)]
# DJI_0419_05_04.png: [('dirty', 0.33386069536209106), ('dirty', 0.31937506794929504)]
# DJI_0766_05_05.png: No detections
# DJI_0616_02_05.png: [('dirty', 0.9781002998352051)]
# DJI_0779_05_05.png: [('dirty', 0.4859861135482788), ('dirty', 0.39463794231414795)]
# DJI_0789_01_05.png: [('dirty', 0.26263079047203064)]
# DJI_0607_04_06.png: No detections
# DJI_0586_02_01.png: [('dirty', 0.5034103393554688), ('dirty', 0.35855141282081604)]
# DJI_0680_01_04.png: No detections
# DJI_0103_02_02.png: [('dirty', 0.5367623567581177), ('dirty', 0.39778149127960205), ('dirty', 0.31586191058158875)]
# DJI_0785_01_01.png: [('dirty', 0.32850122451782227)]
# DJI_0775_06_05.png: [('dirty', 0.47272324562072754), ('dirty', 0.47123727202415466), ('dirty', 0.4047987759113312), ('dirty', 0.36461320519447327), ('dirty', 0.3643355369567871), ('dirty', 0.344370037317276), ('dirty', 0.3195914328098297), ('dirty', 0.31508252024650574), ('dirty', 0.2993473708629608), ('dirty', 0.2509550154209137)]
# DJI_0187_05_08.png: [('dirty', 0.988369345664978), ('dirty', 0.9156390428543091), ('dirty', 0.6391192674636841), ('dirty', 0.3140655755996704)]
# DJI_0032_03_04.png: [('dirty', 0.9598481059074402), ('dirty', 0.863389790058136), ('dirty', 0.8565390110015869), ('dirty', 0.7747977375984192), ('dirty', 0.772331714630127), ('dirty', 0.7561534643173218), ('dirty', 0.7314672470092773), ('dirty', 0.7262004017829895), ('dirty', 0.7117508053779602), ('dirty', 0.6771875619888306), ('dirty', 0.6070191860198975), ('dirty', 0.5800768733024597), ('dirty', 0.45701903104782104), ('dirty', 0.39477062225341797), ('dirty', 0.3881557583808899)]
# DJI_0724_03_06.png: [('dirty', 0.8932573795318604), ('dirty', 0.8577254414558411), ('dirty', 0.5012447237968445), ('dirty', 0.2898688018321991)]
# DJI_0789_02_08.png: [('dirty', 0.45651283860206604)]
# DJI_0352_05_05.png: No detections
# DJI_0217_01_03.png: [('dirty', 0.9538809061050415), ('dirty', 0.9459692239761353), ('dirty', 0.865571916103363), ('dirty', 0.7649775743484497), ('dirty', 0.6879954934120178), ('dirty', 0.5411468148231506), ('dirty', 0.276955783367157)]
# DJI_0420_06_02.png: [('dirty', 0.97611403465271), ('dirty', 0.9175277948379517), ('dirty', 0.8628795742988586), ('dirty', 0.8534683585166931), ('dirty', 0.8374541401863098), ('dirty', 0.7554587721824646), ('dirty', 0.36636221408843994), ('dirty', 0.36014077067375183)]
# DJI_0116_08_06.png: [('dirty', 0.3372693359851837)]
# DJI_0983_06_04.png: [('dirty', 0.9300324320793152), ('dirty', 0.9063062071800232), ('dirty', 0.8393598794937134), ('dirty', 0.8080542683601379)]
# DJI_0690_08_08.png: [('dirty', 0.9438963532447815), ('dirty', 0.6431859731674194), ('dirty', 0.43817198276519775), ('dirty', 0.43169164657592773), ('dirty', 0.2623250186443329)]
# DJI_0996_03_05.png: [('dirty', 0.924697995185852), ('dirty', 0.8208252787590027), ('dirty', 0.7686960697174072), ('dirty', 0.749855637550354), ('dirty', 0.7397424578666687), ('dirty', 0.6986264586448669), ('dirty', 0.5485360622406006), ('dirty', 0.519594132900238), ('dirty', 0.4737544357776642), ('dirty', 0.41234835982322693), ('dirty', 0.410396009683609), ('dirty', 0.29264137148857117), ('dirty', 0.25765877962112427)]
# DJI_0373_02_07.png: [('dirty', 0.7771007418632507), ('dirty', 0.5133476257324219), ('dirty', 0.48954498767852783)]
# DJI_0089_01_02.png: [('dirty', 0.7708491683006287)]
# DJI_0604_08_05.png: [('dirty', 0.5838605761528015), ('dirty', 0.41690099239349365), ('dirty', 0.33814600110054016), ('dirty', 0.3358250558376312)]
# DJI_0119_08_06.png: [('dirty', 0.7435752153396606), ('dirty', 0.5187458992004395), ('dirty', 0.34850966930389404), ('dirty', 0.3435739576816559), ('dirty', 0.2719453275203705)]
# DJI_0963_07_05.png: [('dirty', 0.7422516345977783), ('dirty', 0.6210015416145325), ('dirty', 0.6080849170684814), ('dirty', 0.5543164014816284), ('dirty', 0.5474256873130798), ('dirty', 0.5271340012550354), ('dirty', 0.5030494928359985), ('dirty', 0.4639854431152344), ('dirty', 0.4363582730293274), ('dirty', 0.41763919591903687), ('dirty', 0.40240949392318726), ('dirty', 0.3683413565158844), ('dirty', 0.3680236041545868), ('dirty', 0.36302709579467773), ('dirty', 0.3562329411506653), ('dirty', 0.35098129510879517), ('dirty', 0.33271270990371704), ('dirty', 0.3184443414211273), ('dirty', 0.2765096426010132), ('dirty', 0.26757296919822693)]
# DJI_0726_08_09.png: No detections
# DJI_0605_03_02.png: [('dirty', 0.6611447334289551), ('dirty', 0.4797619581222534), ('dirty', 0.34714508056640625), ('dirty', 0.2984650731086731)]
# DJI_0625_01_06.png: [('dirty', 0.6583293080329895), ('dirty', 0.6037228107452393), ('dirty', 0.5127134323120117), ('dirty', 0.4256274998188019)]
# DJI_0602_01_03.png: No detections
# DJI_0435_05_02.png: [('dirty', 0.8373379111289978), ('dirty', 0.7615793943405151), ('dirty', 0.681378960609436), ('dirty', 0.6202393174171448), ('dirty', 0.5793510675430298), ('dirty', 0.47109195590019226), ('dirty', 0.46532249450683594), ('dirty', 0.4640232026576996), ('dirty', 0.3155056834220886), ('dirty', 0.307341992855072), ('dirty', 0.27755206823349), ('dirty', 0.2636866569519043)]
# DJI_0419_07_01.png: [('dirty', 0.9667239785194397), ('dirty', 0.47113311290740967), ('dirty', 0.4209376871585846), ('dirty', 0.37356340885162354), ('dirty', 0.34179049730300903), ('dirty', 0.3204821050167084)]
# DJI_0333_02_09.png: No detections
# DJI_0263_02_01.png: [('dirty', 0.6222984790802002), ('dirty', 0.3904617726802826), ('dirty', 0.33506178855895996)]
# DJI_0445_03_09.png: [('dirty', 0.7025790810585022), ('dirty', 0.6627387404441833), ('dirty', 0.6234596967697144), ('dirty', 0.6049977540969849), ('dirty', 0.494640588760376), ('dirty', 0.45184728503227234), ('dirty', 0.3712024986743927), ('dirty', 0.35948875546455383), ('dirty', 0.3347715735435486), ('dirty', 0.326148122549057), ('dirty', 0.32227301597595215), ('dirty', 0.2530728578567505)]
# DJI_0027_03_03.png: [('dirty', 0.7501513361930847), ('dirty', 0.6505336761474609), ('dirty', 0.5925738215446472), ('dirty', 0.46776023507118225), ('dirty', 0.4344501197338104), ('dirty', 0.3595999777317047), ('dirty', 0.33128151297569275), ('dirty', 0.32023125886917114)]
# DJI_0785_02_04.png: [('dirty', 0.43207940459251404), ('dirty', 0.4162418246269226)]
# DJI_0197_04_09.png: [('dirty', 0.45469924807548523), ('dirty', 0.2833101749420166)]
# DJI_0711_06_07.png: [('dirty', 0.9273053407669067), ('dirty', 0.5714379549026489), ('dirty', 0.35538336634635925), ('dirty', 0.3541043698787689), ('dirty', 0.3382319509983063)]
# DJI_0114_07_04.png: [('dirty', 0.9097784161567688), ('dirty', 0.7932449579238892), ('dirty', 0.6891188025474548), ('dirty', 0.38067010045051575), ('dirty', 0.37060314416885376)]
# DJI_0778_07_05.png: [('dirty', 0.5004644393920898), ('dirty', 0.46990659832954407), ('dirty', 0.4244447946548462), ('dirty', 0.2911607027053833), ('dirty', 0.2649546265602112)]
# DJI_0224_04_04.png: [('dirty', 0.894814133644104), ('dirty', 0.8243688344955444), ('dirty', 0.7448943257331848), ('dirty', 0.7327816486358643), ('dirty', 0.5090446472167969), ('dirty', 0.4693465828895569), ('dirty', 0.4297288954257965), ('dirty', 0.3602542579174042), ('dirty', 0.33024609088897705), ('dirty', 0.2769988477230072)]
# DJI_0377_07_08.png: [('dirty', 0.5685081481933594)]
# DJI_0034_04_05.png: No detections
# DJI_0266_04_03.png: [('dirty', 0.40868765115737915), ('dirty', 0.29740679264068604)]
# DJI_0606_01_06.png: [('dirty', 0.7080341577529907)]
# DJI_0724_06_07.png: [('dirty', 0.3431927263736725)]
# DJI_0698_01_04.png: [('dirty', 0.6684552431106567)]
# DJI_0200_02_07.png: [('dirty', 0.9022371768951416), ('dirty', 0.9018848538398743), ('dirty', 0.7925560474395752), ('dirty', 0.6677904725074768), ('dirty', 0.3191201388835907)]
# DJI_0693_06_07.png: [('dirty', 0.7713930606842041)]
# DJI_0280_03_03.png: No detections
# DJI_0167_02_05.png: [('dirty', 0.9198004603385925), ('dirty', 0.9191421866416931), ('dirty', 0.7478910088539124), ('dirty', 0.53675776720047), ('dirty', 0.36176130175590515), ('dirty', 0.30260056257247925), ('dirty', 0.2744278609752655)]
# DJI_0361_08_08.png: [('dirty', 0.5987917184829712), ('dirty', 0.5277932286262512), ('dirty', 0.49447357654571533), ('dirty', 0.3921523690223694)]
# DJI_0590_05_02.png: [('dirty', 0.6567366719245911), ('dirty', 0.528615415096283)]
# DJI_0607_05_05.png: [('dirty', 0.6025223731994629), ('dirty', 0.5096091628074646), ('dirty', 0.47633132338523865), ('dirty', 0.4444162845611572), ('dirty', 0.4044871926307678), ('dirty', 0.3647877871990204), ('dirty', 0.26199090480804443), ('dirty', 0.2541047930717468)]
# DJI_0610_05_05.png: [('dirty', 0.6701493263244629)]
# DJI_0599_06_04.png: [('dirty', 0.6290410161018372)]
# DJI_0968_06_05.png: [('dirty', 0.45234614610671997), ('dirty', 0.44724321365356445)]
# DJI_0398_06_05.png: [('dirty', 0.41963842511177063), ('dirty', 0.411430299282074), ('dirty', 0.32069891691207886)]
# DJI_0249_07_02.png: [('dirty', 0.863351583480835), ('dirty', 0.8379059433937073), ('dirty', 0.7818626165390015), ('dirty', 0.7286730408668518), ('dirty', 0.5537498593330383), ('dirty', 0.5083146095275879)]
# DJI_0228_08_02.png: [('dirty', 0.49637097120285034), ('dirty', 0.40908974409103394), ('dirty', 0.3010317385196686)]
# DJI_0788_03_07.png: No detections
# DJI_0995_03_03.png: [('dirty', 0.7962332367897034)]
# DJI_0015_03_03.png: [('dirty', 0.7312825322151184), ('dirty', 0.6703715920448303), ('dirty', 0.4584435820579529), ('dirty', 0.3632790744304657)]
# DJI_0603_02_04.png: No detections
# DJI_0198_02_08.png: [('dirty', 0.8702963590621948), ('dirty', 0.8506221771240234), ('dirty', 0.6821807026863098), ('dirty', 0.6512913107872009), ('dirty', 0.5636842250823975)]
# DJI_0428_04_02.png: No detections
# DJI_0391_05_05.png: [('dirty', 0.5805482268333435), ('dirty', 0.46424180269241333), ('dirty', 0.3821483850479126), ('dirty', 0.34221789240837097), ('dirty', 0.34053272008895874), ('dirty', 0.3347666561603546), ('dirty', 0.2597295939922333)]
# DJI_0217_01_04.png: [('dirty', 0.9320715665817261), ('dirty', 0.9165869355201721), ('dirty', 0.861423909664154), ('dirty', 0.8141098022460938), ('dirty', 0.7935339212417603), ('dirty', 0.7817701697349548), ('dirty', 0.6118573546409607), ('dirty', 0.31472790241241455), ('dirty', 0.2824069559574127), ('dirty', 0.25502461194992065)]
# DJI_0788_02_05.png: No detections
# DJI_0223_04_03.png: [('dirty', 0.9597200751304626), ('dirty', 0.959657609462738), ('dirty', 0.8464120030403137), ('dirty', 0.7906869053840637), ('dirty', 0.6727135181427002), ('dirty', 0.33181890845298767)]
# DJI_0282_03_04.png: [('dirty', 0.3223942518234253)]
# DJI_0782_05_02.png: No detections
# DJI_0784_01_05.png: No detections
# DJI_0272_06_02.png: [('dirty', 0.6535899043083191)]
# DJI_0975_04_09.png: [('dirty', 0.9742006659507751), ('dirty', 0.5686378479003906), ('dirty', 0.3884131908416748), ('dirty', 0.2731400728225708)]
# DJI_0398_05_06.png: [('dirty', 0.42845621705055237), ('dirty', 0.3455715477466583), ('dirty', 0.2736937701702118), ('dirty', 0.2638280391693115)]
# DJI_0585_03_01.png: [('dirty', 0.8040300011634827), ('dirty', 0.5110381245613098), ('dirty', 0.40647730231285095)]
#
# Accuracy: 65/80 = 0.812
#
# === OVERALL RESULTS ===
# Damage detection accuracy: 0.950
# Dirty detection accuracy: 0.812
# Overall accuracy: 0.840
#
# Model saved results to: runs/detect/wind_turbine_damage4/
# Run model.predict() on individual images to see visual results

# %%
import os
import random
from pathlib import Path
from ultralytics import YOLO

#Next version with more data and false negative focused penalty

# Step 1: Expand data selection to 1500 images
base_path = Path("Blades Damages Images + Labels/NordTank586x371")
images_dir = base_path / "images"
labels_dir = base_path / "labels"

def get_all_categorized_images():
    """Get all available images categorized by damage type"""
    damage_files = []
    non_damage_files = []
    
    label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
    
    for label_file in label_files:
        label_path = labels_dir / label_file
        img_name_png = label_file.replace('.txt', '.png')
        
        if not (images_dir / img_name_png).exists():
            continue
            
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        if not lines:
            non_damage_files.append((img_name_png, label_file))
            continue
            
        has_damage = False
        for line in lines:
            if line.strip():
                class_id = int(line.strip().split()[0])
                if class_id == 0:  # Damage class
                    has_damage = True
                    break
        
        if has_damage:
            damage_files.append((img_name_png, label_file))
        else:
            non_damage_files.append((img_name_png, label_file))
    
    return damage_files, non_damage_files

# Get all available data
all_damage, all_non_damage = get_all_categorized_images()
print(f"Available: {len(all_damage)} damage, {len(all_non_damage)} non-damage")

# Sample expanded dataset
max_damage = min(300, len(all_damage))
max_non_damage = min(1200, len(all_non_damage))

selected_damage = random.sample(all_damage, max_damage)
selected_non_damage = random.sample(all_non_damage, max_non_damage)

# Create train/val split (80/20)
all_selected = selected_damage + selected_non_damage
random.shuffle(all_selected)

split_point = int(0.8 * len(all_selected))
train_pairs_extended = all_selected[:split_point]
val_pairs_extended = all_selected[split_point:]

print(f"Extended dataset: {len(train_pairs_extended)} train, {len(val_pairs_extended)} val")

# Step 2: Create new file lists
train_files_ext = [pair[0] for pair in train_pairs_extended]
val_files_ext = [pair[0] for pair in val_pairs_extended]

with open('train_extended.txt', 'w') as f:
    for img_name in train_files_ext:
        f.write(f"{base_path}/images/{img_name}\n")

with open('val_extended.txt', 'w') as f:
    for img_name in val_files_ext:
        f.write(f"{base_path}/images/{img_name}\n")

# Step 3: Create dataset config
dataset_config_extended = """
train: train_extended.txt
val: val_extended.txt

nc: 2
names: ['damage', 'dirty']
"""

with open('dataset_extended.yaml', 'w') as f:
    f.write(dataset_config_extended)

print("Created extended dataset files")

# Step 4: Load your existing best model and continue training
model = YOLO('runs/detect/wind_turbine_damage4/weights/best.pt')

results = model.train(
    data='dataset_extended.yaml',
    epochs=80,            # Fewer epochs since we're fine-tuning
    imgsz=640,
    batch=16,
    
    # Damage-focused loss weighting
    cls=3.0,              # Higher classification loss weight
    box=1.5,              # Slightly higher box regression loss
    
    # Fine-tuning parameters
    lr0=0.001,            # Lower learning rate for fine-tuning
    warmup_epochs=5,      # Warm up period
    patience=20,          # Early stopping patience
    
    name='damage_sensitive_finetuned',
    
    # This ensures we continue from your existing weights
    resume=False          # Don't resume training, but start from pretrained weights
)

print("Fine-tuning completed! Check results in runs/detect/damage_sensitive_finetuned/")
# Out:
# Available: 563 damage, 2432 non-damage
# Extended dataset: 1200 train, 300 val
# Created extended dataset files
# Ultralytics 8.3.202  Python-3.12.7 torch-2.8.0+cpu CPU (Intel Core i5-1035G4 1.10GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=1.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=3.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_extended.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/detect/wind_turbine_damage4/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=damage_sensitive_finetuned, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.20.0 ms, read: 28.928.2 MB/s, size: 189.1 KB)
# train: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 1200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1200/1200 292.3it/s 4.1s0.0s
# train: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# val: Fast image access  (ping: 0.20.1 ms, read: 34.448.9 MB/s, size: 166.8 KB)
# val: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 334.8it/s 0.9s0.1s
# val: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# Plotting labels to C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80         0G     0.3075      7.582       1.16         98        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:299.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 43.7s.7ss
#                    all        300       1005      0.673      0.644      0.632      0.377
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80         0G     0.3117      7.704      1.154         69        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:599.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 43.1s.6ss
#                    all        300       1005      0.648       0.58      0.614      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80         0G      0.321       8.12      1.191         68        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:449.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 43.6s.6ss
#                    all        300       1005      0.714      0.519      0.599      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80         0G     0.3318      8.182       1.21         71        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:279.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 40.5s.3ss
#                    all        300       1005      0.637      0.533      0.558      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80         0G      0.336      8.472      1.226         77        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:349.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42.1s.4ss
#                    all        300       1005      0.766      0.531      0.621      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80         0G     0.3393      8.344       1.23         94        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:0610.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42.6s.6ss
#                    all        300       1005      0.609      0.518      0.572      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80         0G     0.3346      8.067       1.22         80        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:589.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 41.8s.5ss
#                    all        300       1005      0.684       0.56        0.6      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80         0G     0.3359      8.073      1.232         66        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:069.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42.4s.6ss
#                    all        300       1005      0.641      0.502      0.524      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80         0G     0.3404      8.061      1.236         74        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:089.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42.5s.7ss
#                    all        300       1005      0.675      0.582      0.613      0.361
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80         0G     0.3304      7.732      1.208         49        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:229.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 41.1s.4ss
#                    all        300       1005      0.748      0.634      0.688      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80         0G     0.3312      7.676      1.202         70        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:129.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42.4s.7ss
#                    all        300       1005      0.698      0.625      0.669      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80         0G     0.3243      7.541      1.192         80        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:599.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42.6s.5ss
#                    all        300       1005      0.702      0.641      0.664      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80         0G     0.3392      7.699      1.232         49        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:089.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42.1s.5ss
#                    all        300       1005      0.752      0.559      0.644      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80         0G     0.3257       7.63      1.194         78        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:539.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 41.9s.4ss
#                    all        300       1005      0.773      0.549      0.679      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80         0G     0.3219      7.278      1.187         82        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 13:0610.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 45.2s.7ss
#                    all        300       1005       0.75      0.646      0.703      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/80         0G     0.3203      7.208      1.171         81        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:1810.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 46.1s.7ss
#                    all        300       1005       0.75      0.622      0.699      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/80         0G     0.3209      7.119      1.178         83        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:389.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 40.5s.2ss
#                    all        300       1005      0.732      0.628      0.697      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/80         0G     0.3247      7.333      1.182         58        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:2911.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 46.7s.1ss
#                    all        300       1005      0.702      0.569      0.632      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/80         0G     0.3231        7.2       1.19         78        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:279.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 42
0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80         0G     0.2632      4.569      1.033         53        640: 95% ━━━━━━━━━━━─ 71/75 0.1it/s 12:36<37.3s

# %%
from ultralytics import YOLO

# Resume training from the last checkpoint
model = YOLO('runs/detect/damage_sensitive_finetuned/weights/last.pt')

results = model.train(
    resume=True  # This will resume from the last saved checkpoint
)
# Out:
# Ultralytics 8.3.202  Python-3.12.7 torch-2.8.0+cpu CPU (Intel Core i5-1035G4 1.10GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=1.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=3.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_extended.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs\detect\damage_sensitive_finetuned\weights\last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=damage_sensitive_finetuned, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=runs\detect\damage_sensitive_finetuned\weights\last.pt, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.0, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=0, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 1.30.5 ms, read: 54.616.4 MB/s, size: 174.9 KB)
# train: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 1200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1200/1200 177.9it/s 6.7s0.1s
# train: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# val: Fast image access  (ping: 0.70.1 ms, read: 78.615.8 MB/s, size: 179.4 KB)
# val: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 156.9it/s 1.9s0.1s
# val: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# Plotting labels to C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training runs\detect\damage_sensitive_finetuned\weights\last.pt from epoch 73 to 80 total epochs
# Closing dataloader mosaic
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       73/80         0G     0.3371      7.232      1.527         54        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 8:456.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 33.2s.7ss
#                    all        300       1005      0.667      0.617      0.638       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       74/80         0G      0.293      5.454      1.182         40        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 8:487.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 34.1s.7ss
#                    all        300       1005      0.796      0.646      0.733      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       75/80         0G     0.2842       5.13      1.165         39        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:087.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 35.6s.9ss
#                    all        300       1005      0.835      0.688      0.761      0.459
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       76/80         0G     0.2782      5.041      1.123         49        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:2210.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 50.6s.5ss
#                    all        300       1005      0.761      0.726      0.768      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       77/80         0G     0.2751      4.854      1.097         68        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:4610.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 49.3s.4ss
#                    all        300       1005      0.814      0.715      0.762      0.468
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       78/80         0G     0.2754      4.825      1.103         39        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 13:0912.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 57.7s.2ss
#                    all        300       1005      0.794      0.726      0.766      0.467
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       79/80         0G     0.2748      4.773      1.076         40        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 13:069.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 50.1s.5ss
#                    all        300       1005      0.771      0.738      0.764      0.466
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       80/80         0G     0.2712      4.723       1.08         32        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:209.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 47.9s.1ss
#                    all        300       1005      0.741      0.753      0.755      0.468
#
# 8 epochs completed in 1.609 hours.
# Optimizer stripped from C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned\weights\best.pt, 6.2MB
#
# Validating C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned\weights\best.pt...
# Ultralytics 8.3.202  Python-3.12.7 torch-2.8.0+cpu CPU (Intel Core i5-1035G4 1.10GHz)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 37.5s.0ss
#                    all        300       1005      0.837       0.71      0.775      0.497
#                 damage         70         75      0.898      0.823      0.873       0.64
#                  dirty        246        930      0.777      0.597      0.678      0.354
# Speed: 1.2ms preprocess, 96.7ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to C:\Users\dmirk\Sulzer Schmid\runs\detect\damage_sensitive_finetuned

# %%
import os
import random
from pathlib import Path
from ultralytics import YOLO

# Load your new fine-tuned model
model = YOLO('runs/detect/damage_sensitive_finetuned/weights/best.pt')

# Set up paths
base_path = Path("Blades Damages Images + Labels/NordTank586x371")
images_dir = base_path / "images"
labels_dir = base_path / "labels"

def get_unused_test_images():
    """Find images that weren't used in either training run"""
    damage_files = []
    dirty_files = []
    
    # Read both training file lists to exclude all used images
    used_images = set()
    
    # Original training set
    with open('train.txt', 'r') as f:
        used_images.update(line.strip().split('/')[-1] for line in f)
    with open('val.txt', 'r') as f:
        used_images.update(line.strip().split('/')[-1] for line in f)
    
    # Extended training set
    with open('train_extended.txt', 'r') as f:
        used_images.update(line.strip().split('/')[-1] for line in f)
    with open('val_extended.txt', 'r') as f:
        used_images.update(line.strip().split('/')[-1] for line in f)
    
    print(f"Excluding {len(used_images)} previously used images")
    
    # Categorize unused images
    label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
    
    for label_file in label_files:
        img_name = label_file.replace('.txt', '.png')
        
        # Skip if this image was used in any training
        if img_name in used_images:
            continue
            
        if not (images_dir / img_name).exists():
            continue
            
        # Check class
        label_path = labels_dir / label_file
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        if not lines:
            dirty_files.append(img_name)
            continue
            
        has_damage = False
        for line in lines:
            if line.strip():
                class_id = int(line.strip().split()[0])
                if class_id == 0:  # Damage class
                    has_damage = True
                    break
        
        if has_damage:
            damage_files.append(img_name)
        else:
            dirty_files.append(img_name)
    
    return damage_files, dirty_files

# Get completely unused test images
unused_damage, unused_dirty = get_unused_test_images()
print(f"Available unused images: {len(unused_damage)} damage, {len(unused_dirty)} dirty")

# Sample larger test set
test_damage = random.sample(unused_damage, min(100, len(unused_damage)))
test_dirty = random.sample(unused_dirty, min(400, len(unused_dirty)))

print(f"Testing on: {len(test_damage)} damage images, {len(test_dirty)} dirty images")

# Test the model with detailed analysis
def test_damage_sensitive_model(image_list, true_class_name):
    """Test model and analyze confidence distributions"""
    results = []
    high_conf_correct = 0
    low_conf_missed = 0
    
    for img_name in image_list:
        img_path = images_dir / img_name
        
        # Run prediction
        pred_results = model(str(img_path))
        
        # Extract predictions
        detections = []
        if len(pred_results[0].boxes) > 0:
            boxes = pred_results[0].boxes
            for box in boxes:
                class_id = int(box.cls[0].item())
                confidence = float(box.conf[0].item())
                class_name = "damage" if class_id == 0 else "dirty"
                detections.append((class_name, confidence))
        
        # Check if prediction matches true class
        predicted_classes = [det[0] for det in detections]
        has_correct_prediction = true_class_name in predicted_classes
        
        if has_correct_prediction:
            # Check confidence of correct predictions
            correct_confidences = [det[1] for det in detections if det[0] == true_class_name]
            max_conf = max(correct_confidences)
            if max_conf > 0.7:
                high_conf_correct += 1
        else:
            # Missed detection - could be low confidence issue
            if not detections:
                low_conf_missed += 1
        
        results.append({
            'image': img_name,
            'true_class': true_class_name,
            'detections': detections,
            'correct': has_correct_prediction
        })
    
    return results, high_conf_correct, low_conf_missed

# Run comprehensive testing
print("\nTesting damage images...")
damage_results, damage_high_conf, damage_missed = test_damage_sensitive_model(test_damage, 'damage')

print("Testing dirty images...")
dirty_results, dirty_high_conf, dirty_missed = test_damage_sensitive_model(test_dirty, 'dirty')

# Analysis
damage_accuracy = sum(1 for r in damage_results if r['correct']) / len(damage_results)
dirty_accuracy = sum(1 for r in dirty_results if r['correct']) / len(dirty_results)
overall_accuracy = (sum(1 for r in damage_results if r['correct']) + 
                   sum(1 for r in dirty_results if r['correct'])) / (len(damage_results) + len(dirty_results))

print(f"\n=== DAMAGE-SENSITIVE MODEL RESULTS ===")
print(f"Damage detection accuracy: {damage_accuracy:.3f} ({sum(1 for r in damage_results if r['correct'])}/{len(damage_results)})")
print(f"  - High confidence correct: {damage_high_conf}")
print(f"  - No detections (missed): {damage_missed}")

print(f"\nDirty detection accuracy: {dirty_accuracy:.3f} ({sum(1 for r in dirty_results if r['correct'])}/{len(dirty_results)})")
print(f"  - High confidence correct: {dirty_high_conf}")
print(f"  - No detections (missed): {dirty_missed}")

print(f"\nOverall accuracy: {overall_accuracy:.3f}")
print(f"Model saved at: runs/detect/damage_sensitive_finetuned/weights/best.pt")

# Show some examples of missed damage (most critical)
missed_damage = [r for r in damage_results if not r['correct']]
if missed_damage:
    print(f"\n⚠️  CRITICAL: {len(missed_damage)} damage images were missed:")
    for r in missed_damage[:5]:  # Show first 5
        print(f"  {r['image']}: {r['detections'] if r['detections'] else 'No detections'}")
# Out:
# Excluding 1740 previously used images
# Available unused images: 219 damage, 1036 dirty
# Testing on: 100 damage images, 400 dirty images
#
# Testing damage images...
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0702_04_05.png: 416x640 1 dirty, 154.3ms
# Speed: 9.1ms preprocess, 154.3ms inference, 10.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0625_02_07.png: 416x640 1 damage, 1 dirty, 72.3ms
# Speed: 3.2ms preprocess, 72.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0749_04_08.png: 416x640 1 damage, 64.7ms
# Speed: 2.8ms preprocess, 64.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0757_04_07.png: 416x640 1 damage, 1 dirty, 67.8ms
# Speed: 2.2ms preprocess, 67.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0686_03_03.png: 416x640 1 damage, 61.8ms
# Speed: 2.3ms preprocess, 61.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0740_03_04.png: 416x640 1 damage, 64.3ms
# Speed: 2.4ms preprocess, 64.3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0680_04_07.png: 416x640 2 dirtys, 60.5ms
# Speed: 2.3ms preprocess, 60.5ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0624_07_05.png: 416x640 1 damage, 64.4ms
# Speed: 2.7ms preprocess, 64.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0692_04_04.png: 416x640 1 damage, 69.1ms
# Speed: 2.3ms preprocess, 69.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0696_04_04.png: 416x640 1 damage, 66.2ms
# Speed: 2.9ms preprocess, 66.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0755_04_06.png: 416x640 1 damage, 1 dirty, 63.8ms
# Speed: 3.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0594_05_04.png: 416x640 1 damage, 65.3ms
# Speed: 2.4ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0582_06_05.png: 416x640 1 damage, 2 dirtys, 58.7ms
# Speed: 3.1ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0744_03_04.png: 416x640 2 damages, 62.8ms
# Speed: 2.2ms preprocess, 62.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0689_02_02.png: 416x640 1 damage, 59.0ms
# Speed: 3.1ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0699_08_06.png: 416x640 1 damage, 58.9ms
# Speed: 2.2ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0692_06_04.png: 416x640 1 damage, 61.6ms
# Speed: 2.9ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0750_03_08.png: 416x640 1 damage, 1 dirty, 63.2ms
# Speed: 3.3ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0752_04_02.png: 416x640 (no detections), 50.4ms
# Speed: 2.5ms preprocess, 50.4ms inference, 0.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0622_07_06.png: 416x640 1 damage, 1 dirty, 59.6ms
# Speed: 2.1ms preprocess, 59.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0742_02_01.png: 416x640 1 damage, 60.4ms
# Speed: 2.3ms preprocess, 60.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0753_04_05.png: 416x640 2 damages, 58.2ms
# Speed: 2.5ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_
4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0450_05_05.png: 416x640 (no detections), 280.7ms
# Speed: 7.2ms preprocess, 280.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0222_04_02.png: 416x640 4 dirtys, 174.1ms
# Speed: 7.3ms preprocess, 174.1ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0724_03_04.png: 416x640 (no detections), 232.7ms
# Speed: 6.6ms preprocess, 232.7ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0127_05_06.png: 416x640 11 dirtys, 208.0ms
# Speed: 7.3ms preprocess, 208.0ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0444_04_02.png: 416x640 3 dirtys, 211.5ms
# Speed: 7.6ms preprocess, 211.5ms inference, 3.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0163_02_05.png: 416x640 7 dirtys, 222.7ms
# Speed: 7.4ms preprocess, 222.7ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0124_07_06.png: 416x640 7 dirtys, 199.9ms
# Speed: 7.7ms preprocess, 199.9ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0358_05_09.png: 416x640 2 dirtys, 275.5ms
# Speed: 114.8ms preprocess, 275.5ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_01_04.png: 416x640 1 dirty, 153.6ms
# Speed: 4.9ms preprocess, 153.6ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0261_02_05.png: 416x640 1 dirty, 169.8ms
# Speed: 5.5ms preprocess, 169.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0374_03_06.png: 416x640 1 dirty, 184.0ms
# Speed: 21.2ms preprocess, 184.0ms inference, 3.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0188_04_09.png: 416x640 1 dirty, 181.9ms
# Speed: 6.6ms preprocess, 181.9ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0621_08_04.png: 416x640 4 dirtys, 101.7ms
# Speed: 6.7ms preprocess, 101.7ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0782_05_02.png: 416x640 3 dirtys, 100.1ms
# Speed: 4.2ms preprocess, 100.1ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0348_05_03.png: 416x640 6 dirtys, 97.8ms
# Speed: 3.8ms preprocess, 97.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0387_02_05.png: 416x640 2 dirtys, 122.0ms
# Speed: 4.9ms preprocess, 122.0ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0112_07_04.png: 416x640 4 dirtys, 96.1ms
# Speed: 4.6ms preprocess, 96.1ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# === DAMAGE-SENSITIVE MODEL RESULTS ===
# Damage detection accuracy: 0.930 (93/100)
#   - High confidence correct: 54
#   - No detections (missed): 4
#
# Dirty detection accuracy: 0.950 (380/400)
#   - High confidence correct: 191
#   - No detections (missed): 19
#
# Overall accuracy: 0.946
# Model saved at: runs/detect/damage_sensitive_finetuned/weights/best.pt
#
# ⚠️  CRITICAL: 7 damage images were missed:
#   DJI_0702_04_05.png: [('dirty', 0.7788265347480774)]
#   DJI_0680_04_07.png: [('dirty', 0.6258841753005981), ('dirty', 0.5715627670288086)]
#   DJI_0752_04_02.png: No detections
#   DJI_0580_02_04.png: No detections
#   DJI_0695_03_05.png: [('dirty', 0.8707636594772339), ('dirty', 0.7012493014335632)]

# %%
from ultralytics import YOLO

# Load your best existing model
model = YOLO('runs/detect/damage_sensitive_finetuned/weights/best.pt')

# Test with ultra-low threshold for damage detection
def ultra_sensitive_damage_detection(image_list, true_class_name):
    results = []
    
    for img_name in image_list:
        img_path = images_dir / img_name
        
        # Very low confidence threshold, only look for damage class
        pred_results = model.predict(str(img_path), conf=0.02, classes=[0])
        
        # Check if any damage detected
        damage_detected = len(pred_results[0].boxes) > 0
        
        results.append({
            'image': img_name,
            'true_class': true_class_name,
            'damage_detected': damage_detected,
            'correct': damage_detected if true_class_name == 'damage' else not damage_detected
        })
    
    return results

# Test this immediately on your existing test data
damage_results_sensitive = ultra_sensitive_damage_detection(test_damage, 'damage')
dirty_results_sensitive = ultra_sensitive_damage_detection(test_dirty, 'dirty')

damage_recall = sum(1 for r in damage_results_sensitive if r['damage_detected']) / len(damage_results_sensitive)
print(f"Ultra-sensitive damage recall: {damage_recall:.3f}")
# Out:
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_
ms inference, 4.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0686_02_03.png: 416x640 4 damages, 188.4ms
# Speed: 8.5ms preprocess, 188.4ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0752_04_08.png: 416x640 3 damages, 180.6ms
# Speed: 6.7ms preprocess, 180.6ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0734_02_01.png: 416x640 2 damages, 185.8ms
# Speed: 7.1ms preprocess, 185.8ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0588_07_05.png: 416x640 1 damage, 191.1ms
# Speed: 6.5ms preprocess, 191.1ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0703_06_05.png: 416x640 1 damage, 207.3ms
# Speed: 6.7ms preprocess, 207.3ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0226_03_05.png: 416x640 (no detections), 188.8ms
# Speed: 7.9ms preprocess, 188.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0360_04_09.png: 416x640 (no detections), 317.1ms
# Speed: 6.0ms preprocess, 317.1ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0425_03_01.png: 416x640 (no detections), 191.3ms
# Speed: 8.4ms preprocess, 191.3ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0964_03_05.png: 416x640 (no detections), 197.4ms
# Speed: 4.3ms preprocess, 197.4ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0260_04_06.png: 416x640 (no detections), 187.9ms
# Speed: 7.5ms preprocess, 187.9ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0724_04_04.png: 416x640 (no detections), 181.7ms
# Speed: 7.6ms preprocess, 181.7ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0972_03_06.png: 416x640 (no detections), 162.4ms
# Speed: 7.5ms preprocess, 162.4ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0698_01_04.png: 416x640 (no detections), 150.7ms
# Speed: 6.2ms preprocess, 150.7ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0277_04_03.png: 416x640 (no detections), 171.4ms
# Speed: 6.3ms preprocess, 171.4ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0223_05_07.png: 416x640 (no detections), 148.1ms
# Speed: 6.7ms preprocess, 148.1ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0368_06_07.png: 416x640 (no detections), 166.1ms
# Speed: 6.5ms preprocess, 166.1ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0416_08_07.png: 416x640 (no detections), 223.3ms
# Speed: 6.4ms preprocess, 223.3ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0724_04_03.png: 416x640 (no detections), 226.0ms
# Speed: 6.6ms preprocess, 226.0ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0358_04_05.png: 416x640 (no detections), 198.2ms
# Speed: 6.6ms preprocess, 198.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0689_07_07.png: 416x640 (no detections), 172.2ms
# Speed: 5.8ms preprocess, 172.2ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_01_01.png: 416x640 (no detections), 172.8ms
# Speed: 6.0ms preprocess, 172.8ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0362_08_09.png: 416x640 (no detections), 173.1ms
# Speed: 5.8ms preprocess, 173.1ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0982_04_04.png: 416x640 (no detections), 197.0ms
# Speed: 6.7ms preprocess, 197.0ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0052_07_03.png: 416x640 (no detections), 185.5ms
# Speed: 6.8ms preprocess, 185.5ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0706_03_04.png: 416x640 2 damages, 183.9ms
# Speed: 6.4ms preprocess, 183.9ms inference, 3.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0426_04_02.png: 416x640 (no detections), 152.0ms
# Speed: 6.9ms preprocess, 152.0ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0413_06_06.png: 416x640 (no detections), 171.6ms
# Speed: 7.6ms preprocess, 171.6ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0422_06_03.png: 416x640 (no detections), 164.6ms
# Speed: 3.5ms preprocess, 164.6ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0188_05_08.png: 416x640 (no detections), 176.9ms
# Speed: 5.2ms preprocess, 176.9ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0106_01_04.png: 416x640 (no detections), 150.0ms
# Speed: 6.9ms preprocess, 150.0ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0723_06_04.png: 416x640 (no detections), 176.0ms
# Speed: 5.7ms preprocess, 176.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0271_05_02.png: 416x640 (no detections), 196.0ms
# Speed: 6.5ms preprocess, 196.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0372_07_06.png: 416x640 (no detections), 199.2ms
# Speed: 5.6ms preprocess, 199.2ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0978_05_08.png: 416x640 (no detections), 185.0ms
# Speed: 7.2ms preprocess, 185.0ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0420_04_05.png: 416x640 (no detections), 188.8ms
# Speed: 6.6ms preprocess, 188.8ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0989_05_03.png: 416x640 (no detections), 196.8ms
# Speed: 7.1ms preprocess, 196.8ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0586_05_01.png: 416x640 (no detections), 176.5ms
# Speed: 5.6ms preprocess, 176.5ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0589_03_01.png: 416x640 (no detections), 189.0ms
# Speed: 7.2ms preprocess, 189.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0597_02_05.png: 416x640 (no detections), 192.0ms
# Speed: 6.8ms preprocess, 192.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0039_05_06.png: 416x640 (no detections), 190.2ms
# Speed: 6.4ms preprocess, 190.2ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0183_03_05.png: 416x640 (no detections), 168.8ms
# Speed: 7.1ms preprocess, 168.8ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0357_05_09.png: 416x640 (no detections), 157.6ms
# Speed: 6.4ms preprocess, 157.6ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0336_02_08.png: 416x640 (no detections), 194.5ms
# Speed: 7.3ms preprocess, 194.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0222_02_04.png: 416x640 (no detections), 146.8ms
# Speed: 6.9ms preprocess, 146.8ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0362_08_08.png: 416x640 (no detections), 161.6ms
# Speed: 6.6ms preprocess, 161.6ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0443_03_05.png: 416x640 (no detections), 157.4ms
# Speed: 6.2ms preprocess, 157.4ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0711_07_08.png: 416x640 (no detections), 154.9ms
# Speed: 5.9ms preprocess, 154.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0376_05_09.png: 416x640 (no detections), 156.7ms
# Speed: 7.0ms preprocess, 156.7ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0394_04_05.png: 416x640 (no detections), 614.8ms
# Speed: 10.5ms preprocess, 614.8ms inference, 5.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0771_05_05.png: 416x640 (no detections), 236.6ms
# Speed: 5.7ms preprocess, 236.6ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0227_05_02.png: 416x640 (no detections), 211.9ms
# Speed: 5.3ms preprocess, 211.9ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0616_05_03.png: 416x640 (no detections), 171.7ms
# Speed: 6.7ms preprocess, 171.7ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0228_06_02.png: 416x640 (no detections), 183.2ms
# Speed: 6.6ms preprocess, 183.2ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0453_06_06.png: 416x640 (no detections), 200.1ms
# Speed: 5.8ms preprocess, 200.1ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0770_02_04.png: 416x640 (no detections), 209.9ms
# Speed: 6.5ms preprocess, 209.9ms inference, 3.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0039_04_04.png: 416x640 (no detections), 184.0ms
# Speed: 7.5ms preprocess, 184.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0198_02_08.png: 416x640 (no detections), 183.9ms
# Speed: 5.4ms preprocess, 183.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0694_02_04.png: 416x640 (no detections), 202.5ms
# Speed: 6.1ms preprocess, 202.5ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_04_01.png: 416x640 (no detections), 196.3ms
# Speed: 7.1ms preprocess, 196.3ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0725_03_08.png: 416x640 (no detections), 215.5ms
# Speed: 7.5ms preprocess, 215.5ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0775_05_05.png: 416x640 (no detections), 198.8ms
# Speed: 5.5ms preprocess, 198.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0217_01_02.png: 416x640 (no detections), 185.6ms
# Speed: 6.6ms preprocess, 185.6ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0042_06_07.png: 416x640 (no detections), 269.7ms
# Speed: 6.7ms preprocess, 269.7ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0260_01_06.png: 416x640 (no detections), 166.8ms
# Speed: 11.0ms preprocess, 166.8ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0355_03_06.png: 416x640 (no detections), 162.9ms
# Speed: 5.4ms preprocess, 162.9ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0603_07_04.png: 416x640 (no detections), 183.0ms
# Speed: 7.5ms preprocess, 183.0ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0595_05_03.png: 416x640 (no detections), 189.2ms
# Speed: 5.8ms preprocess, 189.2ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0257_02_05.png: 416x640 (no detections), 173.1ms
# Speed: 6.1ms preprocess, 173.1ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0218_01_02.png: 416x640 (no detections), 172.9ms
# Speed: 6.8ms preprocess, 172.9ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0788_07_05.png: 416x640 (no detections), 207.0ms
# Speed: 7.9ms preprocess, 207.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0351_03_03.png: 416x640 (no detections), 207.3ms
# Speed: 6.8ms preprocess, 207.3ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0427_05_01.png: 416x640 (no detections), 219.2ms
# Speed: 7.3ms preprocess, 219.2ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0422_05_03.png: 416x640 (no detections), 181.9ms
# Speed: 6.6ms preprocess, 181.9ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0262_02_04.png: 416x640 (no detections), 246.9ms
# Speed: 4.2ms preprocess, 246.9ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0691_01_04.png: 416x640 (no detections), 248.5ms
# Speed: 7.5ms preprocess, 248.5ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0751_04_09.png: 416x640 (no detections), 214.3ms
# Speed: 3.8ms preprocess, 214.3ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0697_08_07.png: 416x640 1 damage, 218.5ms
# Speed: 7.5ms preprocess, 218.5ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0195_04_05.png: 416x640 (no detections), 211.1ms
# Speed: 4.4ms preprocess, 211.1ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0444_04_08.png: 416x640 (no detections), 187.5ms
# Speed: 3.7ms preprocess, 187.5ms inference, 3.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0222_03_03.png: 416x640 (no detections), 199.0ms
# Speed: 8.8ms preprocess, 199.0ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0776_05_05.png: 416x640 (no detections), 309.2ms
# Speed: 7.4ms preprocess, 309.2ms inference, 13.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0701_04_05.png: 416x640 (no detections), 190.7ms
# Speed: 6.7ms preprocess, 190.7ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0201_02_06.png: 416x640 (no detections), 189.1ms
# Speed: 6.0ms preprocess, 189.1ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0021_03_04.png: 416x640 (no detections), 188.4ms
# Speed: 5.4ms preprocess, 188.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0358_06_09.png: 416x640 (no detections), 175.0ms
# Speed: 6.9ms preprocess, 175.0ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0251_06_02.png: 416x640 (no detections), 167.9ms
# Speed: 7.5ms preprocess, 167.9ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0362_01_09.png: 416x640 (no detections), 172.7ms
# Speed: 3.4ms preprocess, 172.7ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0603_02_04.png: 416x640 (no detections), 171.9ms
# Speed: 5.6ms preprocess, 171.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0607_04_06.png: 416x640 1 damage, 168.5ms
# Speed: 7.0ms preprocess, 168.5ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0395_03_08.png: 416x640 (no detections), 186.2ms
# Speed: 4.6ms preprocess, 186.2ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0249_08_01.png: 416x640 (no detections), 208.8ms
# Speed: 5.4ms preprocess, 208.8ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0348_06_03.png: 416x640 (no detections), 197.3ms
# Speed: 5.8ms preprocess, 197.3ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0186_04_06.png: 416x640 (no detections), 209.8ms
# Speed: 6.6ms preprocess, 209.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0376_05_07.png: 416x640 (no detections), 197.0ms
# Speed: 4.8ms preprocess, 197.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0363_08_08.png: 416x640 (no detections), 198.4ms
# Speed: 5.6ms preprocess, 198.4ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0969_07_05.png: 416x640 (no detections), 200.1ms
# Speed: 5.8ms preprocess, 200.1ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0680_05_07.png: 416x640 (no detections), 321.5ms
# Speed: 6.2ms preprocess, 321.5ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0105_06_04.png: 416x640 (no detections), 174.1ms
# Speed: 3.8ms preprocess, 174.1ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0376_06_08.png: 416x640 (no detections), 182.8ms
# Speed: 4.5ms preprocess, 182.8ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0619_08_03.png: 416x640 (no detections), 217.0ms
# Speed: 4.4ms preprocess, 217.0ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0100_06_05.png: 416x640 (no detections), 205.5ms
# Speed: 8.3ms preprocess, 205.5ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0326_03_06.png: 416x640 (no detections), 189.9ms
# Speed: 6.4ms preprocess, 189.9ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0378_04_05.png: 416x640 (no detections), 210.8ms
# Speed: 6.2ms preprocess, 210.8ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# ...
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0223_03_02.png: 416x640 (no detections), 193.1ms
# Speed: 7.0ms preprocess, 193.1ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0384_02_02.png: 416x640 (no detections), 178.0ms
# Speed: 6.1ms preprocess, 178.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0445_04_05.png: 416x640 (no detections), 170.4ms
# Speed: 5.3ms preprocess, 170.4ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0727_04_09.png: 416x640 5 damages, 153.5ms
# Speed: 6.3ms preprocess, 153.5ms inference, 3.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0215_01_04.png: 416x640 (no detections), 172.5ms
# Speed: 7.2ms preprocess, 172.5ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0349_05_03.png: 416x640 (no detections), 159.4ms
# Speed: 7.1ms preprocess, 159.4ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0089_04_05.png: 416x640 (no detections), 160.9ms
# Speed: 6.4ms preprocess, 160.9ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0008_03_05.png: 416x640 (no detections), 301.9ms
# Speed: 7.2ms preprocess, 301.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0329_02_07.png: 416x640 (no detections), 175.5ms
# Speed: 6.6ms preprocess, 175.5ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0350_03_04.png: 416x640 (no detections), 173.2ms
# Speed: 6.4ms preprocess, 173.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0252_06_03.png: 416x640 (no detections), 190.6ms
# Speed: 4.8ms preprocess, 190.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0617_07_02.png: 416x640 (no detections), 182.6ms
# Speed: 5.9ms preprocess, 182.6ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0981_04_05.png: 416x640 (no detections), 180.0ms
# Speed: 4.0ms preprocess, 180.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0428_03_01.png: 416x640 (no detections), 198.3ms
# Speed: 8.0ms preprocess, 198.3ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0996_03_06.png: 416x640 (no detections), 205.8ms
# Speed: 4.4ms preprocess, 205.8ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0722_05_04.png: 416x640 (no detections), 211.3ms
# Speed: 7.4ms preprocess, 211.3ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0111_06_04.png: 416x640 (no detections), 196.0ms
# Speed: 5.0ms preprocess, 196.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0448_05_04.png: 416x640 (no detections), 187.7ms
# Speed: 7.1ms preprocess, 187.7ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0056_08_04.png: 416x640 (no detections), 195.5ms
# Speed: 3.8ms preprocess, 195.5ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0443_05_04.png: 416x640 (no detections), 200.9ms
# Speed: 7.1ms preprocess, 200.9ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0327_01_06.png: 416x640 (no detections), 288.3ms
# Speed: 4.5ms preprocess, 288.3ms inference, 3.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0373_01_06.png: 416x640 (no detections), 190.3ms
# Speed: 11.1ms preprocess, 190.3ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0224_04_07.png: 416x640 (no detections), 194.6ms
# Speed: 4.3ms preprocess, 194.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0363_06_08.png: 416x640 (no detections), 191.8ms
# Speed: 3.5ms preprocess, 191.8ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0699_06_06.png: 416x640 (no detections), 172.5ms
# Speed: 6.3ms preprocess, 172.5ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0982_06_04.png: 416x640 (no detections), 176.3ms
# Speed: 4.0ms preprocess, 176.3ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0995_03_04.png: 416x640 (no detections), 223.8ms
# Speed: 4.8ms preprocess, 223.8ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0351_04_05.png: 416x640 (no detections), 202.9ms
# Speed: 6.2ms preprocess, 202.9ms inference, 3.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0385_03_04.png: 416x640 (no detections), 204.0ms
# Speed: 6.2ms preprocess, 204.0ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0360_05_09.png: 416x640 (no detections), 202.3ms
# Speed: 4.2ms preprocess, 202.3ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0334_02_08.png: 416x640 (no detections), 192.2ms
# Speed: 4.1ms preprocess, 192.2ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0374_01_07.png: 416x640 (no detections), 362.2ms
# Speed: 6.4ms preprocess, 362.2ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0264_01_02.png: 416x640 (no detections), 200.1ms
# Speed: 6.3ms preprocess, 200.1ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0979_05_08.png: 416x640 (no detections), 220.9ms
# Speed: 5.0ms preprocess, 220.9ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0178_03_06.png: 416x640 (no detections), 198.4ms
# Speed: 6.8ms preprocess, 198.4ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0607_01_06.png: 416x640 (no detections), 211.9ms
# Speed: 7.4ms preprocess, 211.9ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0331_04_05.png: 416x640 (no detections), 182.1ms
# Speed: 5.7ms preprocess, 182.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0606_01_06.png: 416x640 (no detections), 186.1ms
# Speed: 5.0ms preprocess, 186.1ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_03_02.png: 416x640 (no detections), 190.9ms
# Speed: 5.2ms preprocess, 190.9ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0326_04_05.png: 416x640 (no detections), 189.2ms
# Speed: 3.7ms preprocess, 189.2ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0044_06_07.png: 416x640 (no detections), 177.5ms
# Speed: 4.0ms preprocess, 177.5ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0788_04_01.png: 416x640 (no detections), 175.8ms
# Speed: 5.6ms preprocess, 175.8ms inference, 1.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0383_03_03.png: 416x640 (no detections), 176.7ms
# Speed: 6.2ms preprocess, 176.7ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0092_02_03.png: 416x640 (no detections), 174.7ms
# Speed: 6.1ms preprocess, 174.7ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0726_06_07.png: 416x640 (no detections), 176.6ms
# Speed: 6.2ms preprocess, 176.6ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0445_03_09.png: 416x640 (no detections), 169.3ms
# Speed: 5.7ms preprocess, 169.3ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0453_03_01.png: 416x640 (no detections), 177.9ms
# Speed: 6.8ms preprocess, 177.9ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0280_03_03.png: 416x640 (no detections), 167.3ms
# Speed: 5.9ms preprocess, 167.3ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0450_05_05.png: 416x640 (no detections), 176.0ms
# Speed: 6.9ms preprocess, 176.0ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0222_04_02.png: 416x640 (no detections), 160.8ms
# Speed: 5.9ms preprocess, 160.8ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0724_03_04.png: 416x640 5 damages, 178.8ms
# Speed: 6.8ms preprocess, 178.8ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0127_05_06.png: 416x640 (no detections), 176.3ms
# Speed: 7.1ms preprocess, 176.3ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0444_04_02.png: 416x640 (no detections), 177.1ms
# Speed: 6.6ms preprocess, 177.1ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0163_02_05.png: 416x640 (no detections), 214.5ms
# Speed: 7.3ms preprocess, 214.5ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0124_07_06.png: 416x640 (no detections), 187.7ms
# Speed: 6.9ms preprocess, 187.7ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0358_05_09.png: 416x640 (no detections), 150.0ms
# Speed: 6.0ms preprocess, 150.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_01_04.png: 416x640 (no detections), 144.4ms
# Speed: 5.9ms preprocess, 144.4ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0261_02_05.png: 416x640 (no detections), 167.8ms
# Speed: 6.7ms preprocess, 167.8ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0374_03_06.png: 416x640 (no detections), 177.6ms
# Speed: 6.2ms preprocess, 177.6ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0188_04_09.png: 416x640 (no detections), 178.8ms
# Speed: 4.4ms preprocess, 178.8ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0621_08_04.png: 416x640 (no detections), 205.0ms
# Speed: 3.6ms preprocess, 205.0ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0782_05_02.png: 416x640 (no detections), 167.6ms
# Speed: 6.7ms preprocess, 167.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0348_05_03.png: 416x640 (no detections), 192.0ms
# Speed: 6.6ms preprocess, 192.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0387_02_05.png: 416x640 (no detections), 202.7ms
# Speed: 6.5ms preprocess, 202.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0112_07_04.png: 416x640 (no detections), 201.3ms
# Speed: 7.0ms preprocess, 201.3ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
# Ultra-sensitive damage recall: 0.960

# %%
# Analyze the ultra-sensitive test results
total_images = len(damage_results_sensitive) + len(dirty_results_sensitive)
actually_damaged = len(damage_results_sensitive)  # 100
actually_dirty = len(dirty_results_sensitive)    # 400

# Count how many were flagged as damaged by the ultra-sensitive model
flagged_as_damaged = (sum(1 for r in damage_results_sensitive if r['damage_detected']) + 
                      sum(1 for r in dirty_results_sensitive if r['damage_detected']))

print(f"=== ULTRA-SENSITIVE MODEL ANALYSIS ===")
print(f"Total test images: {total_images}")
print(f"Actually damaged: {actually_damaged} ({actually_damaged/total_images:.1%})")
print(f"Actually dirty: {actually_dirty} ({actually_dirty/total_images:.1%})")
print(f"Flagged as damaged: {flagged_as_damaged} ({flagged_as_damaged/total_images:.1%})")

# False positives and false negatives
false_negatives = sum(1 for r in damage_results_sensitive if not r['damage_detected'])
false_positives = sum(1 for r in dirty_results_sensitive if r['damage_detected'])

print(f"\n=== CRITICAL METRICS ===")
print(f"False negatives (missed damage): {false_negatives} ({false_negatives/actually_damaged:.1%})")
print(f"False positives (dirty flagged as damage): {false_positives} ({false_positives/actually_dirty:.1%})")
print(f"Inspection workload reduction: {(total_images - flagged_as_damaged)/total_images:.1%}")

# Show the missed damage cases
missed_damage = [r['image'] for r in damage_results_sensitive if not r['damage_detected']]
print(f"\n⚠️  MISSED DAMAGE IMAGES:")
for img in missed_damage:
    print(f"  {img}")
# Out:
# === ULTRA-SENSITIVE MODEL ANALYSIS ===
# Total test images: 500
# Actually damaged: 100 (20.0%)
# Actually dirty: 400 (80.0%)
# Flagged as damaged: 110 (22.0%)
#
# === CRITICAL METRICS ===
# False negatives (missed damage): 4 (4.0%)
# False positives (dirty flagged as damage): 14 (3.5%)
# Inspection workload reduction: 78.0%
#
# ⚠️  MISSED DAMAGE IMAGES:
#   DJI_0680_04_07.png
#   DJI_0580_02_04.png
#   DJI_0695_03_05.png
#   DJI_0687_06_04.png

# %%
#New model with highly increased false damage weight

# Load your best existing model as starting point
model = YOLO('runs/detect/damage_sensitive_finetuned/weights/best.pt')

# Train with extreme damage sensitivity
results = model.train(
    data='dataset_extended.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    
    # Extreme loss weighting - much higher than before
    cls=15.0,   # Was 3.0, now 15.0 - massive penalty for misclassification
    box=2.0,    # Slightly higher box loss
    
    # Very conservative training to avoid overfitting
    lr0=0.0005,    # Lower learning rate
    patience=25,    # More patience for early stopping
    
    name='ultra_damage_sensitive',
    
    # Optional: Add more augmentation to make model more robust
    degrees=5.0,    # Slight rotation
    translate=0.1,  # Slight translation
)

print("Training ultra damage-sensitive model...")
# Out:
# Ultralytics 8.3.202  Python-3.12.7 torch-2.8.0+cpu CPU (Intel Core i5-1035G4 1.10GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=2.0, cache=False, cfg=None, classes=None, close_mosaic=10, cls=15.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset_extended.yaml, degrees=5.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.0005, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/detect/damage_sensitive_finetuned/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=ultra_damage_sensitive, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=25, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\dmirk\Sulzer Schmid\runs\detect\ultra_damage_sensitive, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]
# Model summary: 129 layers, 3,011,238 parameters, 3,011,222 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 109.220.0 MB/s, size: 189.1 KB)
# train: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 1200 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1200/1200 392.5it/s 3.1s0.0s
# train: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 71.312.9 MB/s, size: 166.8 KB)
# val: Scanning Blades Damages Images + Labels\NordTank586x371\labels... 300 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 300/300 396.7it/s 0.8s0.0s
# val: New cache created: Blades Damages Images + Labels\NordTank586x371\labels.cache
# Plotting labels to C:\Users\dmirk\Sulzer Schmid\runs\detect\ultra_damage_sensitive\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.0005' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\dmirk\Sulzer Schmid\runs\detect\ultra_damage_sensitive
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G     0.3821      25.14      1.101         97        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:219.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 38.7s.2ss
#                    all        300       1005      0.767      0.733      0.756      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      0.392      27.76      1.113         68        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:467.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 39.5s.4ss
#                    all        300       1005      0.787      0.661      0.735      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G     0.4018      29.31      1.138         70        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 13:0110.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 50.8s.5ss
#                    all        300       1005      0.754      0.672      0.711      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G     0.4116      31.05      1.154         75        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:5510.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 49.1s.3ss
#                    all        300       1005      0.754      0.585      0.642      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G     0.4151      31.18      1.165         76        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 12:4210.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 48.3s.3ss
#                    all        300       1005      0.797      0.558      0.668      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G     0.4143      30.91      1.161         95        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:247.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 36.7s.9ss
#                    all        300       1005      0.677      0.618      0.662      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G     0.4128      30.74      1.155         81        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:587.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 35.9s.0ss
#                    all        300       1005      0.775      0.606      0.682       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G     0.4161      31.44      1.168         67        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:457.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 36.4s.0ss
#                    all        300       1005      0.799      0.643      0.704      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G     0.4249      31.65      1.179         74        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 10:197.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 38.3s.1ss
#                    all        300       1005      0.737      0.643      0.711      0.371
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G     0.4186      30.78      1.173         50        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:498.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 36.3s.0ss
#                    all        300       1005      0.743      0.662      0.678      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         0G      0.418      30.91      1.167         72        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 10:018.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 37.0s.1ss
#                    all        300       1005      0.816      0.637      0.717       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         0G     0.4229      31.26      1.182         81        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:587.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 36.5s.0ss
#                    all        300       1005      0.794      0.643      0.714      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         0G     0.4295      31.51      1.185         50        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:607.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 37.3s.0ss
#                    all        300       1005      0.761      0.661      0.707      0.382
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100         0G     0.4174      31.18      1.165         79        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 10:217.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 37.4s.0ss
#                    all        300       1005       0.75       0.61      0.684      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100         0G     0.4163      30.06      1.162         84        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 11:428.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 37.8s.0ss
#                    all        300       1005      0.756      0.643      0.702      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100         0G     0.4166      30.25      1.157         78        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:579.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 38.4s.0ss
#                    all        300       1005      0.728      0.602      0.662      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100         0G      0.419      30.32      1.163         84        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:577.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 35.6s.8ss
#                    all        300       1005      0.729      0.639      0.701      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100         0G     0.4156      31.11      1.165         59        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:177.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 33.5s.6ss
#                    all        300       1005      0.785      0.668      0.707       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100         0G     0.4135      30.03      1.158         79        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:157.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 34.1s.7ss
#                    all        300       1005      0.753      0.619      0.676      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         0G     0.4215      30.09      1.192         83        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:147.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 34.5s.7ss
#                    all        300       1005      0.767      0.656      0.718       0.36
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100         0G     0.4217      30.65      1.172         91        640: 100% ━━━━━━━━━━━━ 75/75 0.2it/s 8:186.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 31.0s.4ss
#                    all        300       1005      0.741      0.663      0.727      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100         0G     0.4151      29.42      1.164         73        640: 100% ━━━━━━━━━━━━ 75/75 0.2it/s 7:465.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 29.0s.1ss
#                    all        300       1005      0.779      0.571      0.674      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100         0G     0.4155      29.53      1.157         61        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:279.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.2it/s 40.5s.6ss
#                    all        300       1005      0.758      0.613      0.673       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100         0G     0.4184      29.74      1.176        113        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:497.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 35.9s.0ss
#                    all        300       1005      0.763      0.662      0.719      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100         0G      0.412       29.4      1.157         66        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:358.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 35.3s.8ss
#                    all        300       1005      0.732      0.585      0.673      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100         0G     0.4109      30.01      1.159         71        640: 100% ━━━━━━━━━━━━ 75/75 0.1it/s 9:157.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 39.9s.6ss
#                    all        300       1005      0.811      0.676      0.736      0.393
# EarlyStopping: Training stopped early as no improvement observed in last 25 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=25) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 26 epochs completed in 4.727 hours.
# Optimizer stripped from C:\Users\dmirk\Sulzer Schmid\runs\detect\ultra_damage_sensitive\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\dmirk\Sulzer Schmid\runs\detect\ultra_damage_sensitive\weights\best.pt, 6.2MB
#
# Validating C:\Users\dmirk\Sulzer Schmid\runs\detect\ultra_damage_sensitive\weights\best.pt...
# Ultralytics 8.3.202  Python-3.12.7 torch-2.8.0+cpu CPU (Intel Core i5-1035G4 1.10GHz)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 32.7s.4ss
#                    all        300       1005      0.766      0.733      0.756      0.413
#                 damage         70         75      0.829      0.843      0.851      0.499
#                  dirty        246        930      0.702      0.624      0.662      0.327
# Speed: 0.9ms preprocess, 84.9ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to C:\Users\dmirk\Sulzer Schmid\runs\detect\ultra_damage_sensitive
# Training ultra damage-sensitive model...

# %%
# Test the ultra-sensitive model
ultra_model = YOLO('runs/detect/ultra_damage_sensitive/weights/best.pt')

# Run the same test with very low threshold
def test_ultra_model(image_list, true_class_name):
    results = []
    for img_name in image_list:
        img_path = images_dir / img_name
        pred_results = ultra_model.predict(str(img_path), conf=0.01, classes=[0])
        damage_detected = len(pred_results[0].boxes) > 0
        results.append({
            'damage_detected': damage_detected,
            'correct': damage_detected if true_class_name == 'damage' else not damage_detected
        })
    return results

# Test on your same test set
ultra_damage_results = test_ultra_model(test_damage, 'damage')
ultra_dirty_results = test_ultra_model(test_dirty, 'dirty')

damage_recall = sum(1 for r in ultra_damage_results if r['damage_detected']) / len(ultra_damage_results)
print(f"Ultra model damage recall: {damage_recall:.3f}")
# Out:
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0702_04_05.png: 416x640 5 damages, 116.3ms
# Speed: 8.7ms preprocess, 116.3ms inference, 6.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0625_02_07.png: 416x640 1 damage, 64.4ms
# Speed: 3.2ms preprocess, 64.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0749_04_08.png: 416x640 1 damage, 57.8ms
# Speed: 2.6ms preprocess, 57.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0757_04_07.png: 416x640 2 damages, 59.7ms
# Speed: 2.3ms preprocess, 59.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0686_03_03.png: 416x640 1 damage, 68.7ms
# Speed: 2.9ms preprocess, 68.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0740_03_04.png: 416x640 2 damages, 70.7ms
# Speed: 2.7ms preprocess, 70.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_
3ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0982_04_04.png: 416x640 (no detections), 56.2ms
# Speed: 2.1ms preprocess, 56.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0052_07_03.png: 416x640 (no detections), 56.6ms
# Speed: 2.4ms preprocess, 56.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0706_03_04.png: 416x640 3 damages, 94.8ms
# Speed: 2.3ms preprocess, 94.8ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0426_04_02.png: 416x640 (no detections), 131.7ms
# Speed: 2.5ms preprocess, 131.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0413_06_06.png: 416x640 (no detections), 51.1ms
# Speed: 2.4ms preprocess, 51.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0422_06_03.png: 416x640 (no detections), 58.4ms
# Speed: 2.2ms preprocess, 58.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0188_05_08.png: 416x640 (no detections), 48.1ms
# Speed: 2.3ms preprocess, 48.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0106_01_04.png: 416x640 (no detections), 48.7ms
# Speed: 2.0ms preprocess, 48.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0723_06_04.png: 416x640 (no detections), 53.6ms
# Speed: 2.2ms preprocess, 53.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0271_05_02.png: 416x640 (no detections), 58.0ms
# Speed: 2.1ms preprocess, 58.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0372_07_06.png: 416x640 (no detections), 85.5ms
# Speed: 3.1ms preprocess, 85.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0978_05_08.png: 416x640 (no detections), 81.1ms
# Speed: 3.1ms preprocess, 81.1ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0420_04_05.png: 416x640 (no detections), 64.9ms
# Speed: 2.6ms preprocess, 64.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0989_05_03.png: 416x640 (no detections), 62.7ms
# Speed: 2.4ms preprocess, 62.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0586_05_01.png: 416x640 (no detections), 56.1ms
# Speed: 2.6ms preprocess, 56.1ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0589_03_01.png: 416x640 (no detections), 59.0ms
# Speed: 3.4ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0597_02_05.png: 416x640 (no detections), 64.9ms
# Speed: 2.3ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0039_05_06.png: 416x640 (no detections), 57.6ms
# Speed: 2.2ms preprocess, 57.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0183_03_05.png: 416x640 (no detections), 58.2ms
# Speed: 2.2ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0357_05_09.png: 416x640 (no detections), 54.2ms
# Speed: 3.1ms preprocess, 54.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0336_02_08.png: 416x640 (no detections), 52.7ms
# Speed: 2.4ms preprocess, 52.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0222_02_04.png: 416x640 (no detections), 51.1ms
# Speed: 2.1ms preprocess, 51.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0362_08_08.png: 416x640 (no detections), 47.8ms
# Speed: 2.2ms preprocess, 47.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0443_03_05.png: 416x640 (no detections), 51.6ms
# Speed: 2.1ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0711_07_08.png: 416x640 (no detections), 52.1ms
# Speed: 2.2ms preprocess, 52.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0376_05_09.png: 416x640 (no detections), 47.9ms
# Speed: 2.5ms preprocess, 47.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0394_04_05.png: 416x640 (no detections), 53.3ms
# Speed: 2.2ms preprocess, 53.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0771_05_05.png: 416x640 (no detections), 62.4ms
# Speed: 2.4ms preprocess, 62.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0227_05_02.png: 416x640 (no detections), 47.2ms
# Speed: 2.4ms preprocess, 47.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0616_05_03.png: 416x640 (no detections), 50.7ms
# Speed: 2.3ms preprocess, 50.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0228_06_02.png: 416x640 (no detections), 49.0ms
# Speed: 2.2ms preprocess, 49.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0453_06_06.png: 416x640 (no detections), 46.8ms
# Speed: 2.4ms preprocess, 46.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0770_02_04.png: 416x640 (no detections), 47.4ms
# Speed: 2.2ms preprocess, 47.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0039_04_04.png: 416x640 (no detections), 49.1ms
# Speed: 2.3ms preprocess, 49.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0198_02_08.png: 416x640 (no detections), 48.9ms
# Speed: 2.2ms preprocess, 48.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0694_02_04.png: 416x640 6 damages, 49.8ms
# Speed: 2.2ms preprocess, 49.8ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_04_01.png: 416x640 2 damages, 59.1ms
# Speed: 2.4ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0725_03_08.png: 416x640 (no detections), 48.9ms
# Speed: 2.8ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0775_05_05.png: 416x640 (no detections), 47.2ms
# Speed: 2.2ms preprocess, 47.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0217_01_02.png: 416x640 (no detections), 61.4ms
# Speed: 2.4ms preprocess, 61.4ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0042_06_07.png: 416x640 (no detections), 147.2ms
# Speed: 2.5ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0260_01_06.png: 416x640 (no detections), 67.2ms
# Speed: 2.6ms preprocess, 67.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0355_03_06.png: 416x640 (no detections), 64.2ms
# Speed: 2.9ms preprocess, 64.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0603_07_04.png: 416x640 (no detections), 60.4ms
# Speed: 2.4ms preprocess, 60.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0595_05_03.png: 416x640 (no detections), 54.4ms
# Speed: 2.3ms preprocess, 54.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0257_02_05.png: 416x640 (no detections), 63.5ms
# Speed: 2.1ms preprocess, 63.5ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0218_01_02.png: 416x640 (no detections), 61.4ms
# Speed: 2.8ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0788_07_05.png: 416x640 (no detections), 63.1ms
# Speed: 2.7ms preprocess, 63.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0351_03_03.png: 416x640 (no detections), 63.3ms
# Speed: 2.3ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0427_05_01.png: 416x640 (no detections), 52.8ms
# Speed: 2.4ms preprocess, 52.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0422_05_03.png: 416x640 (no detections), 53.1ms
# Speed: 2.7ms preprocess, 53.1ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0262_02_04.png: 416x640 (no detections), 60.4ms
# Speed: 2.5ms preprocess, 60.4ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0691_01_04.png: 416x640 (no detections), 59.6ms
# Speed: 2.6ms preprocess, 59.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0751_04_09.png: 416x640 (no detections), 62.9ms
# Speed: 2.4ms preprocess, 62.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0697_08_07.png: 416x640 1 damage, 65.3ms
# Speed: 2.3ms preprocess, 65.3ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0195_04_05.png: 416x640 (no detections), 79.1ms
# Speed: 2.7ms preprocess, 79.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0444_04_08.png: 416x640 (no detections), 64.3ms
# Speed: 2.2ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0222_03_03.png: 416x640 (no detections), 64.7ms
# Speed: 2.4ms preprocess, 64.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0776_05_05.png: 416x640 (no detections), 61.2ms
# Speed: 2.4ms preprocess, 61.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0701_04_05.png: 416x640 (no detections), 64.1ms
# Speed: 2.7ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0201_02_06.png: 416x640 (no detections), 66.4ms
# Speed: 2.4ms preprocess, 66.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0021_03_04.png: 416x640 (no detections), 51.8ms
# Speed: 2.5ms preprocess, 51.8ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0358_06_09.png: 416x640 (no detections), 53.2ms
# Speed: 2.5ms preprocess, 53.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0251_06_02.png: 416x640 (no detections), 58.5ms
# Speed: 2.6ms preprocess, 58.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0362_01_09.png: 416x640 (no detections), 122.9ms
# Speed: 2.6ms preprocess, 122.9ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0603_02_04.png: 416x640 (no detections), 62.0ms
# Speed: 2.4ms preprocess, 62.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0607_04_06.png: 416x640 1 damage, 60.9ms
# Speed: 2.6ms preprocess, 60.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0395_03_08.png: 416x640 (no detections), 63.6ms
# Speed: 2.6ms preprocess, 63.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0249_08_01.png: 416x640 (no detections), 60.4ms
# Speed: 2.6ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0348_06_03.png: 416x640 (no detections), 59.7ms
# Speed: 2.3ms preprocess, 59.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0186_04_06.png: 416x640 (no detections), 57.5ms
# Speed: 2.4ms preprocess, 57.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0376_05_07.png: 416x640 (no detections), 69.7ms
# Speed: 2.6ms preprocess, 69.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0363_08_08.png: 416x640 (no detections), 68.3ms
# Speed: 2.2ms preprocess, 68.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0969_07_05.png: 416x640 (no detections), 65.9ms
# Speed: 2.3ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0680_05_07.png: 416x640 (no detections), 82.8ms
# Speed: 2.5ms preprocess, 82.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0105_06_04.png: 416x640 (no detections), 70.3ms
# Speed: 2.9ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0376_06_08.png: 416x640 (no detections), 68.9ms
# Speed: 2.2ms preprocess, 68.9ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0619_08_03.png: 416x640 (no detections), 64.6ms
# Speed: 2.6ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0100_06_05.png: 416x640 (no detections), 64.4ms
# Speed: 2.6ms preprocess, 64.4ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0326_03_06.png: 416x640 (no detections), 87.6ms
# Speed: 3.8ms preprocess, 87.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0378_04_05.png: 416x640 (no detections), 77.1ms
# Speed: 3.0ms preprocess, 77.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0985_05_03.png: 416x640 (no detections), 96.0ms
# Speed: 2.5ms preprocess, 96.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0441_05_03.png: 416x640 (no detections), 77.3ms
# Speed: 2.7ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# ...
# Speed: 2.4ms preprocess, 59.7ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0223_03_02.png: 416x640 (no detections), 60.3ms
# Speed: 2.2ms preprocess, 60.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0384_02_02.png: 416x640 (no detections), 54.3ms
# Speed: 2.6ms preprocess, 54.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0445_04_05.png: 416x640 (no detections), 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0727_04_09.png: 416x640 (no detections), 59.2ms
# Speed: 2.1ms preprocess, 59.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0215_01_04.png: 416x640 (no detections), 94.9ms
# Speed: 2.5ms preprocess, 94.9ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0349_05_03.png: 416x640 (no detections), 70.0ms
# Speed: 2.8ms preprocess, 70.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0089_04_05.png: 416x640 (no detections), 48.2ms
# Speed: 2.2ms preprocess, 48.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0008_03_05.png: 416x640 (no detections), 71.6ms
# Speed: 3.1ms preprocess, 71.6ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0329_02_07.png: 416x640 (no detections), 69.5ms
# Speed: 2.2ms preprocess, 69.5ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0350_03_04.png: 416x640 (no detections), 50.1ms
# Speed: 2.1ms preprocess, 50.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0252_06_03.png: 416x640 (no detections), 56.7ms
# Speed: 2.8ms preprocess, 56.7ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0617_07_02.png: 416x640 (no detections), 79.3ms
# Speed: 2.4ms preprocess, 79.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0981_04_05.png: 416x640 (no detections), 56.4ms
# Speed: 2.5ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0428_03_01.png: 416x640 (no detections), 70.9ms
# Speed: 2.8ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0996_03_06.png: 416x640 (no detections), 59.8ms
# Speed: 3.0ms preprocess, 59.8ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0722_05_04.png: 416x640 1 damage, 55.3ms
# Speed: 2.3ms preprocess, 55.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0111_06_04.png: 416x640 (no detections), 48.3ms
# Speed: 2.2ms preprocess, 48.3ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0448_05_04.png: 416x640 (no detections), 65.9ms
# Speed: 2.3ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0056_08_04.png: 416x640 (no detections), 59.4ms
# Speed: 2.5ms preprocess, 59.4ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0443_05_04.png: 416x640 (no detections), 60.2ms
# Speed: 2.2ms preprocess, 60.2ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0327_01_06.png: 416x640 (no detections), 47.1ms
# Speed: 2.2ms preprocess, 47.1ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0373_01_06.png: 416x640 (no detections), 59.9ms
# Speed: 2.3ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0224_04_07.png: 416x640 (no detections), 56.1ms
# Speed: 2.2ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0363_06_08.png: 416x640 (no detections), 105.0ms
# Speed: 2.8ms preprocess, 105.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0699_06_06.png: 416x640 1 damage, 111.6ms
# Speed: 3.9ms preprocess, 111.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0982_06_04.png: 416x640 (no detections), 87.5ms
# Speed: 2.4ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0995_03_04.png: 416x640 (no detections), 85.3ms
# Speed: 3.2ms preprocess, 85.3ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0351_04_05.png: 416x640 (no detections), 89.7ms
# Speed: 2.7ms preprocess, 89.7ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0385_03_04.png: 416x640 (no detections), 89.0ms
# Speed: 2.6ms preprocess, 89.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0360_05_09.png: 416x640 (no detections), 98.6ms
# Speed: 3.0ms preprocess, 98.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0334_02_08.png: 416x640 (no detections), 109.1ms
# Speed: 2.9ms preprocess, 109.1ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0374_01_07.png: 416x640 (no detections), 122.1ms
# Speed: 3.2ms preprocess, 122.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0264_01_02.png: 416x640 (no detections), 117.8ms
# Speed: 3.5ms preprocess, 117.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0979_05_08.png: 416x640 (no detections), 155.4ms
# Speed: 3.0ms preprocess, 155.4ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0178_03_06.png: 416x640 (no detections), 165.9ms
# Speed: 5.3ms preprocess, 165.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0607_01_06.png: 416x640 (no detections), 110.6ms
# Speed: 3.7ms preprocess, 110.6ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0331_04_05.png: 416x640 (no detections), 97.2ms
# Speed: 3.1ms preprocess, 97.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0606_01_06.png: 416x640 (no detections), 107.0ms
# Speed: 3.8ms preprocess, 107.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_03_02.png: 416x640 (no detections), 146.7ms
# Speed: 2.8ms preprocess, 146.7ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0326_04_05.png: 416x640 (no detections), 120.6ms
# Speed: 3.8ms preprocess, 120.6ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0044_06_07.png: 416x640 (no detections), 96.8ms
# Speed: 2.9ms preprocess, 96.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0788_04_01.png: 416x640 (no detections), 94.9ms
# Speed: 2.8ms preprocess, 94.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0383_03_03.png: 416x640 (no detections), 103.9ms
# Speed: 2.7ms preprocess, 103.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0092_02_03.png: 416x640 (no detections), 120.4ms
# Speed: 3.2ms preprocess, 120.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0726_06_07.png: 416x640 (no detections), 90.4ms
# Speed: 2.9ms preprocess, 90.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0445_03_09.png: 416x640 (no detections), 90.4ms
# Speed: 3.1ms preprocess, 90.4ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0453_03_01.png: 416x640 (no detections), 92.2ms
# Speed: 3.5ms preprocess, 92.2ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0280_03_03.png: 416x640 (no detections), 88.0ms
# Speed: 3.6ms preprocess, 88.0ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0450_05_05.png: 416x640 (no detections), 109.0ms
# Speed: 3.1ms preprocess, 109.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0222_04_02.png: 416x640 (no detections), 132.3ms
# Speed: 3.1ms preprocess, 132.3ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0724_03_04.png: 416x640 2 damages, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0127_05_06.png: 416x640 (no detections), 79.1ms
# Speed: 3.7ms preprocess, 79.1ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0444_04_02.png: 416x640 (no detections), 79.2ms
# Speed: 3.4ms preprocess, 79.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0163_02_05.png: 416x640 (no detections), 74.8ms
# Speed: 2.6ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0124_07_06.png: 416x640 (no detections), 74.1ms
# Speed: 2.6ms preprocess, 74.1ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0358_05_09.png: 416x640 (no detections), 70.2ms
# Speed: 2.3ms preprocess, 70.2ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0786_01_04.png: 416x640 (no detections), 70.4ms
# Speed: 2.9ms preprocess, 70.4ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0261_02_05.png: 416x640 (no detections), 73.0ms
# Speed: 2.6ms preprocess, 73.0ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0374_03_06.png: 416x640 (no detections), 79.5ms
# Speed: 2.9ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0188_04_09.png: 416x640 (no detections), 71.3ms
# Speed: 3.0ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0621_08_04.png: 416x640 3 damages, 73.0ms
# Speed: 2.8ms preprocess, 73.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0782_05_02.png: 416x640 (no detections), 72.6ms
# Speed: 3.4ms preprocess, 72.6ms inference, 1.1ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0348_05_03.png: 416x640 (no detections), 70.6ms
# Speed: 3.0ms preprocess, 70.6ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0387_02_05.png: 416x640 (no detections), 71.7ms
# Speed: 2.8ms preprocess, 71.7ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 C:\Users\dmirk\Sulzer Schmid\Blades Damages Images + Labels\NordTank586x371\images\DJI_0112_07_04.png: 416x640 (no detections), 72.9ms
# Speed: 2.9ms preprocess, 72.9ms inference, 1.2ms postprocess per image at shape (1, 3, 416, 640)
# Ultra model damage recall: 0.980

# %%
# Analyze the ultra-sensitive test results
total_images = len(test_damage) + len(test_dirty)
actually_damaged = len(test_damage)  # Should be 100
actually_dirty = len(test_dirty)    # Should be 400

# Count how many were flagged as damaged by the ultra-sensitive model
flagged_as_damaged = (sum(1 for r in ultra_damage_results if r['damage_detected']) + 
                      sum(1 for r in ultra_dirty_results if r['damage_detected']))

print(f"=== ULTRA-SENSITIVE MODEL ANALYSIS ===")
print(f"Total test images: {total_images}")
print(f"Actually damaged: {actually_damaged} ({actually_damaged/total_images:.1%})")
print(f"Actually dirty: {actually_dirty} ({actually_dirty/total_images:.1%})")
print(f"Flagged as damaged: {flagged_as_damaged} ({flagged_as_damaged/total_images:.1%})")

# False positives and false negatives
false_negatives = sum(1 for r in ultra_damage_results if not r['damage_detected'])
false_positives = sum(1 for r in ultra_dirty_results if r['damage_detected'])

print(f"\n=== CRITICAL METRICS ===")
print(f"False negatives (missed damage): {false_negatives} ({false_negatives/actually_damaged:.1%})")
print(f"False positives (dirty flagged as damage): {false_positives} ({false_positives/actually_dirty:.1%})")
print(f"Inspection workload reduction: {(total_images - flagged_as_damaged)/total_images:.1%}")

# Show the missed damage cases - corrected to match actual data structure
if false_negatives > 0:
    print(f"\n⚠️  MISSED DAMAGE IMAGES ({false_negatives}):")
    for i, (result, img_name) in enumerate(zip(ultra_damage_results, test_damage)):
        if not result['damage_detected']:
            print(f"  {i+1}. {img_name}")
else:
    print(f"\n✅ NO DAMAGE MISSED!")

print(f"\nModel performance summary:")
print(f"- Started with 93% damage detection")
print(f"- Ultra-sensitive model: 98% damage detection") 
print(f"- Only {false_negatives} out of {actually_damaged} damaged blades missed")
print(f"- Inspection workload: {flagged_as_damaged} images ({flagged_as_damaged/total_images:.1%}) need human inspection")
print(f"- Workload reduction: {(total_images - flagged_as_damaged)/total_images:.1%}")
# Out:
# === ULTRA-SENSITIVE MODEL ANALYSIS ===
# Total test images: 500
# Actually damaged: 100 (20.0%)
# Actually dirty: 400 (80.0%)
# Flagged as damaged: 123 (24.6%)
#
# === CRITICAL METRICS ===
# False negatives (missed damage): 2 (2.0%)
# False positives (dirty flagged as damage): 25 (6.2%)
# Inspection workload reduction: 75.4%
#
# ⚠️  MISSED DAMAGE IMAGES (2):
#   7. DJI_0680_04_07.png
#   94. DJI_0687_06_04.png
#
# Model performance summary:
# - Started with 93% damage detection
# - Ultra-sensitive model: 98% damage detection
# - Only 2 out of 100 damaged blades missed
# - Inspection workload: 123 images (24.6%) need human inspection
# - Workload reduction: 75.4%

# %%
import os
from pathlib import Path

# Get ALL available images from the dataset
def get_all_dataset_images():
    """Get every image in the dataset with their true labels"""
    all_damage_images = []
    all_dirty_images = []
    
    label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]
    
    for label_file in label_files:
        img_name = label_file.replace('.txt', '.png')
        
        # Check if image exists
        if not (images_dir / img_name).exists():
            continue
            
        # Determine true class
        label_path = labels_dir / label_file
        with open(label_path, 'r') as f:
            lines = f.readlines()
        
        if not lines:
            all_dirty_images.append(img_name)
            continue
            
        has_damage = False
        for line in lines:
            if line.strip():
                class_id = int(line.strip().split()[0])
                if class_id == 0:  # Damage class
                    has_damage = True
                    break
        
        if has_damage:
            all_damage_images.append(img_name)
        else:
            all_dirty_images.append(img_name)
    
    return all_damage_images, all_dirty_images

# Get all images in dataset
all_damage_imgs, all_dirty_imgs = get_all_dataset_images()
print(f"Found {len(all_damage_imgs)} damage images, {len(all_dirty_imgs)} dirty images")
print(f"Total dataset: {len(all_damage_imgs) + len(all_dirty_imgs)} images")

# Test on entire dataset with optimal threshold (conf=0.005)
def test_entire_dataset(damage_images, dirty_images):
    """Test ultra-sensitive model on entire dataset"""
    print("\nTesting on entire dataset...")
    
    # Test damage images
    damage_detected = 0
    for i, img_name in enumerate(damage_images):
        if i % 100 == 0:
            print(f"Processing damage images: {i}/{len(damage_images)}")
        
        img_path = images_dir / img_name
        pred_results = ultra_model.predict(str(img_path), conf=0.005, classes=[0], verbose=False)
        if len(pred_results[0].boxes) > 0:
            damage_detected += 1
    
    # Test dirty images  
    dirty_flagged_as_damage = 0
    for i, img_name in enumerate(dirty_images):
        if i % 500 == 0:
            print(f"Processing dirty images: {i}/{len(dirty_images)}")
            
        img_path = images_dir / img_name
        pred_results = ultra_model.predict(str(img_path), conf=0.005, classes=[0], verbose=False)
        if len(pred_results[0].boxes) > 0:
            dirty_flagged_as_damage += 1
    
    return damage_detected, dirty_flagged_as_damage

# Run full dataset test
detected_damage, false_positives = test_entire_dataset(all_damage_imgs, all_dirty_imgs)

# Calculate final metrics
total_images = len(all_damage_imgs) + len(all_dirty_imgs)
total_flagged = detected_damage + false_positives
damage_recall = detected_damage / len(all_damage_imgs)
false_positive_rate = false_positives / len(all_dirty_imgs)

print(f"\n=== FULL DATASET RESULTS ===")
print(f"Total images tested: {total_images}")
print(f"Actually damaged: {len(all_damage_imgs)}")
print(f"Actually dirty: {len(all_dirty_imgs)}")
print(f"")
print(f"Damage recall: {detected_damage}/{len(all_damage_imgs)} = {damage_recall:.1%}")
print(f"Missed damage: {len(all_damage_imgs) - detected_damage}")
print(f"")
print(f"Total flagged for inspection: {total_flagged}/{total_images} = {total_flagged/total_images:.1%}")
print(f"False positives: {false_positives}/{len(all_dirty_imgs)} = {false_positive_rate:.1%}")
print(f"")
print(f"Workload reduction: {(total_images - total_flagged)/total_images:.1%}")
print(f"Human inspectors only need to check {total_flagged} images instead of {total_images}")
# Out:
# Found 563 damage images, 2432 dirty images
# Total dataset: 2995 images
#
# Testing on entire dataset...
# Processing damage images: 0/563
# Processing damage images: 100/563
# Processing damage images: 200/563
# Processing damage images: 300/563
# Processing damage images: 400/563
# Processing damage images: 500/563
# Processing dirty images: 0/2432
# Processing dirty images: 500/2432
# Processing dirty images: 1000/2432
# Processing dirty images: 1500/2432
# Processing dirty images: 2000/2432
#
# === FULL DATASET RESULTS ===
# Total images tested: 2995
# Actually damaged: 563
# Actually dirty: 2432
#
# Damage recall: 559/563 = 99.3%
# Missed damage: 4
#
# Total flagged for inspection: 805/2995 = 26.9%
# False positives: 246/2432 = 10.1%
#
# Workload reduction: 73.1%
# Human inspectors only need to check 805 images instead of 2995

# %%
#Even lower confidence intervall
# Test with conf=0.001 on the 4 missed damage cases
def ultra_low_threshold_test(damage_images, dirty_images):
    """Test with conf=0.001"""
    print("Testing with conf=0.001 on entire dataset...")
    
    # Test damage images
    damage_detected = 0
    for i, img_name in enumerate(damage_images):
        if i % 100 == 0:
            print(f"Processing damage images: {i}/{len(damage_images)}")
        
        img_path = images_dir / img_name
        pred_results = ultra_model.predict(str(img_path), conf=0.001, classes=[0], verbose=False)
        if len(pred_results[0].boxes) > 0:
            damage_detected += 1
    
    # Test dirty images  
    dirty_flagged_as_damage = 0
    for i, img_name in enumerate(dirty_images):
        if i % 500 == 0:
            print(f"Processing dirty images: {i}/{len(dirty_images)}")
            
        img_path = images_dir / img_name
        pred_results = ultra_model.predict(str(img_path), conf=0.001, classes=[0], verbose=False)
        if len(pred_results[0].boxes) > 0:
            dirty_flagged_as_damage += 1
    
    return damage_detected, dirty_flagged_as_damage

# Test with ultra-low threshold
detected_damage_001, false_positives_001 = ultra_low_threshold_test(all_damage_imgs, all_dirty_imgs)

total_flagged_001 = detected_damage_001 + false_positives_001
damage_recall_001 = detected_damage_001 / len(all_damage_imgs)
false_positive_rate_001 = false_positives_001 / len(all_dirty_imgs)

print(f"\n=== ULTRA-LOW THRESHOLD (conf=0.001) RESULTS ===")
print(f"Damage recall: {detected_damage_001}/{len(all_damage_imgs)} = {damage_recall_001:.1%}")
print(f"Missed damage: {len(all_damage_imgs) - detected_damage_001}")
print(f"")
print(f"Total flagged for inspection: {total_flagged_001}/{total_images} = {total_flagged_001/total_images:.1%}")
print(f"False positives: {false_positives_001}/{len(all_dirty_imgs)} = {false_positive_rate_001:.1%}")
print(f"Workload reduction: {(total_images - total_flagged_001)/total_images:.1%}")

print(f"\n=== COMPARISON ===")
print(f"conf=0.005: {559/563:.1%} recall, 805 flagged ({805/2995:.1%})")
print(f"conf=0.001: {damage_recall_001:.1%} recall, {total_flagged_001} flagged ({total_flagged_001/total_images:.1%})")
print(f"Trade-off: +{total_flagged_001-805} more inspections to catch {detected_damage_001-559} more damage cases")
# Out:
# Testing with conf=0.001 on entire dataset...
# Processing damage images: 0/563
# Processing damage images: 100/563
# Processing damage images: 200/563
# Processing damage images: 300/563
# Processing damage images: 400/563
# Processing damage images: 500/563
# Processing dirty images: 0/2432
# Processing dirty images: 500/2432
# Processing dirty images: 1000/2432
# Processing dirty images: 1500/2432
# Processing dirty images: 2000/2432
#
# === ULTRA-LOW THRESHOLD (conf=0.001) RESULTS ===
# Damage recall: 563/563 = 100.0%
# Missed damage: 0
#
# Total flagged for inspection: 1357/2995 = 45.3%
# False positives: 794/2432 = 32.6%
# Workload reduction: 54.7%
#
# === COMPARISON ===
# conf=0.005: 99.3% recall, 805 flagged (26.9%)
# conf=0.001: 100.0% recall, 1357 flagged (45.3%)
# Trade-off: +552 more inspections to catch 4 more damage cases
